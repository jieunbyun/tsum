# %%
from ndtools import staged_max_flow as smf
from typing import Any, Dict, List, Sequence

from pathlib import Path
import json
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

from tsum import tsum
import torch

import time

# %% [markdown]
# # Utility functions

# %% [markdown]
# For use in plotting later.

# %%
def relabel_selected_keys(
    selected_keys: Sequence[str],
    nodes: Dict[str, Dict[str, Any]],
    edges: Dict[str, Dict[str, Any]],
    *,
    node_label: str = "node_id",
    edge_label_fmt: str = "({from_}, {to})",
    keep_unmatched: bool = True,
) -> List[str]:
    """
    Given a list of comp_id keys (e.g., ['x1','x29',...]), return a same-length list
    where each key is replaced by:
      - node label (default: node id like 'n1') if comp_id matches a node
      - '(from,to)' if comp_id matches an edge
    First match wins if multiple components share a comp_id.
    Node takes precedence over edge if both match.
    """

    comp_to_label: Dict[str, str] = {}

    for n_id, n in nodes.items():
        comp_id = n.get("comp_id")
        if comp_id and comp_id not in comp_to_label:
            comp_to_label[comp_id] = n_id if node_label == "node_id" else str(n.get(node_label, n_id))

    for _, e in edges.items():
        comp_id = e.get("comp_id")
        if comp_id and comp_id not in comp_to_label:
            comp_to_label[comp_id] = edge_label_fmt.format(from_=e.get("from"), to=e.get("to"))

    out_keys: List[str] = []
    for k in selected_keys:
        if k in comp_to_label:
            out_keys.append(comp_to_label[k])
        else:
            if keep_unmatched:
                out_keys.append(k)
            else:
                continue

    return out_keys

# %% [markdown]
# # System reliability
#
# ## Case 1: Original system
#
# First load data.

# %%
DATASET = Path(r"data")

nodes = json.loads((DATASET / "nodes.json").read_text(encoding="utf-8"))
edges = json.loads((DATASET / "edges.json").read_text(encoding="utf-8"))
probs_dict = json.loads((DATASET / "probs.json").read_text(encoding="utf-8"))

# %%
def s_fun(comps_st):
    flow, sys_st_str, min_comp_state = smf.sys_fun( comps_st, nodes, edges, probs_dict, target_flow = 90.0 )

    sys_st = 1 if sys_st_str == 's' else 0
    return flow, sys_st, None

row_names = list(probs_dict.keys())
n_state = 2  # binary states: 0, 1

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
probs = [[probs_dict[n]['0']['p'], probs_dict[n]['1']['p']] for n in row_names]
probs = torch.tensor(probs, dtype=torch.float32, device=device)

# %%
TSUMPATH = Path("tsum_res")

sys_surv_st = 1  # system survival state

rules_mat_surv = torch.load(TSUMPATH / f"rules_geq_{sys_surv_st}.pt", map_location="cpu")
rules_mat_surv = rules_mat_surv.to(device)
rules_mat_fail = torch.load(TSUMPATH / f"rules_leq_{sys_surv_st-1}.pt", map_location="cpu")
rules_mat_fail = rules_mat_fail.to(device)

# %% [markdown]
# ## System marginal probability

# %%
st = time.time()

pr_cond = tsum.get_comp_cond_sys_prob(
    rules_mat_surv,
    rules_mat_fail,
    probs,
    comps_st_cond = {},
    row_names = row_names,
    s_fun = s_fun,
    sys_surv_st = sys_surv_st,
    n_sample = 10_000_000
)

et = time.time()
print(f"Time elapsed: {et - st:.2f} seconds\n")
print(f"P(sys >= {sys_surv_st}) = {pr_cond['survival']:.3e}")
print(f"P(sys <= {sys_surv_st-1} ) = {pr_cond['failure']:.3e}\n")
# Out:
# Time elapsed: 13.62 seconds
#
# P(sys >= 1) = 7.673e-01
# P(sys <= 0 ) = 2.327e-01

# %% [markdown]
# # Component Importance Measures
#
# For each component $X$ we compute three importance measures:
#
# - **Birnbaum's measure (BI)**: $BI(x) = P(S=1 \mid X=1) - P(S=1 \mid X=0)$
# - **Risk Achievement Worth (RAW)**: $RAW(x) = \dfrac{P(S=0 \mid X=1)}{P(S=0)}$
# - **Risk Reduction Worth (RRW)**: $RRW(x) = \dfrac{P(S=0 \mid X=0)}{P(S=0)}$
#
# All three derive from the same two conditional probabilities, so they are computed together to avoid duplicate sampling.

# %%
bi_dict = {}
raw_dict = {}
rrw_dict = {}

p_sys_fail = pr_cond['failure']
p_sys_surv = pr_cond['survival']

for x in probs_dict.keys():
    print(f"Calculating measures for {x}..")

    ps1_x1 = tsum.get_comp_cond_sys_prob(
        rules_mat_surv,
        rules_mat_fail,
        probs,
        comps_st_cond = {x: 1},
        row_names = row_names,
        s_fun = s_fun,
        sys_surv_st = sys_surv_st,
        n_sample = 10_000_000
    )

    ps1_x0 = tsum.get_comp_cond_sys_prob(
        rules_mat_surv,
        rules_mat_fail,
        probs,
        comps_st_cond = {x: 0},
        row_names = row_names,
        s_fun = s_fun,
        sys_surv_st = sys_surv_st,
        n_sample = 10_000_000
    )

    p_surv_x1 = ps1_x1['survival']
    p_surv_x0 = ps1_x0['survival']
    p_fail_x1 = ps1_x1['failure']
    p_fail_x0 = ps1_x0['failure']

    # Birnbaum's measure
    bi = max(0.0, p_surv_x1 - p_surv_x0)

    # Risk Achievement Worth: P(S=0|X=1) / P(S=0)
    raw = p_fail_x1 / p_sys_fail if p_sys_fail > 0 else float('inf')

    # Risk Reduction Worth: P(S=0|X=0) / P(S=0)
    rrw = p_fail_x0 / p_sys_fail if p_sys_fail > 0 else float('inf')

    bi_dict[x] = bi
    raw_dict[x] = raw
    rrw_dict[x] = rrw

    print(f"BI({x}) = {bi:.3e}, RAW({x}) = {raw:.3e}, RRW({x}) = {rrw:.3e}\n")

results_dict = {
    "P_sys_surv": p_sys_surv,
    "P_sys_fail": p_sys_fail,
    "BI": bi_dict,
    "RAW": raw_dict,
    "RRW": rrw_dict,
}

out_path = TSUMPATH / "importance_measures.json"
with open(out_path, "w") as f:
    json.dump(results_dict, f, indent=4)

print(f"Results saved to {out_path}")
# Out:
# Calculating measures for x1..
# BI(x1) = 4.387e-02, RAW(x1) = 9.952e-01, RRW(x1) = 1.184e+00
#
# Calculating measures for x2..
# BI(x2) = 4.439e-02, RAW(x2) = 9.942e-01, RRW(x2) = 1.185e+00
#
# Calculating measures for x3..
# BI(x3) = 8.358e-02, RAW(x3) = 9.901e-01, RRW(x3) = 1.349e+00
#
# Calculating measures for x4..
# BI(x4) = 6.179e-02, RAW(x4) = 9.920e-01, RRW(x4) = 1.258e+00
#
# Calculating measures for x5..
# BI(x5) = 0.000e+00, RAW(x5) = 9.993e-01, RRW(x5) = 9.992e-01
#
# Calculating measures for x6..
# BI(x6) = 6.338e-02, RAW(x6) = 9.924e-01, RRW(x6) = 1.265e+00
#
# Calculating measures for x7..
# BI(x7) = 6.329e-02, RAW(x7) = 9.931e-01, RRW(x7) = 1.265e+00
#
# Calculating measures for x8..
# BI(x8) = 0.000e+00, RAW(x8) = 1.001e+00, RRW(x8) = 1.001e+00
#
# Calculating measures for x9..
# BI(x9) = 1.005e-04, RAW(x9) = 9.995e-01, RRW(x9) = 1.000e+00
#
# Calculating measures for x10..
# BI(x10) = 7.909e-01, RAW(x10) = 8.989e-01, RRW(x10) = 4.298e+00
#
# Calculating measures for x11..
# BI(x11) = 1.898e-04, RAW(x11) = 9.999e-01, RRW(x11) = 1.001e+00
#
# Calculating measures for x12..
# BI(x12) = 7.908e-01, RAW(x12) = 8.992e-01, RRW(x12) = 4.298e+00
#
# Calculating measures for x13..
# BI(x13) = 0.000e+00, RAW(x13) = 1.001e+00, RRW(x13) = 1.000e+00
#
# Calculating measures for x14..
# BI(x14) = 4.418e-02, RAW(x14) = 9.944e-01, RRW(x14) = 1.184e+00
#
# Calculating measures for x15..
# BI(x15) = 4.438e-02, RAW(x15) = 9.935e-01, RRW(x15) = 1.184e+00
#
# Calculating measures for x16..
# BI(x16) = 7.910e-01, RAW(x16) = 8.985e-01, RRW(x16) = 4.298e+00
#
# Calculating measures for x17..
# BI(x17) = 7.913e-01, RAW(x17) = 8.972e-01, RRW(x17) = 4.298e+00
#
# Calculating measures for x18..
# BI(x18) = 7.910e-01, RAW(x18) = 8.985e-01, RRW(x18) = 4.298e+00
#
# Calculating measures for x19..
# BI(x19) = 8.345e-02, RAW(x19) = 9.900e-01, RRW(x19) = 1.349e+00
#
# Calculating measures for x20..
# BI(x20) = 6.176e-02, RAW(x20) = 9.924e-01, RRW(x20) = 1.258e+00
#
# Calculating measures for x21..
# BI(x21) = 0.000e+00, RAW(x21) = 1.001e+00, RRW(x21) = 9.992e-01
#
# Calculating measures for x22..
# BI(x22) = 8.381e-02, RAW(x22) = 9.894e-01, RRW(x22) = 1.350e+00
#
# Calculating measures for x23..
# BI(x23) = 6.191e-02, RAW(x23) = 9.919e-01, RRW(x23) = 1.258e+00
#
# Calculating measures for x24..
# BI(x24) = 1.229e-04, RAW(x24) = 9.991e-01, RRW(x24) = 9.997e-01
#
# Calculating measures for x25..
# BI(x25) = 7.911e-01, RAW(x25) = 8.978e-01, RRW(x25) = 4.298e+00
#
# Calculating measures for x26..
# BI(x26) = 6.195e-02, RAW(x26) = 9.920e-01, RRW(x26) = 1.258e+00
#
# Calculating measures for x27..
# BI(x27) = 0.000e+00, RAW(x27) = 1.000e+00, RRW(x27) = 1.000e+00
#
# Calculating measures for x28..
# BI(x28) = 0.000e+00, RAW(x28) = 1.001e+00, RRW(x28) = 1.001e+00
#
# Calculating measures for x29..
# BI(x29) = 6.339e-02, RAW(x29) = 9.919e-01, RRW(x29) = 1.264e+00
#
# Calculating measures for x30..
# BI(x30) = 6.316e-02, RAW(x30) = 9.923e-01, RRW(x30) = 1.264e+00
#
# Calculating measures for x31..
# BI(x31) = 7.590e-05, RAW(x31) = 9.999e-01, RRW(x31) = 1.000e+00
#
# Calculating measures for x32..
# BI(x32) = 0.000e+00, RAW(x32) = 1.000e+00, RRW(x32) = 9.999e-01
#
# Calculating measures for x33..
# BI(x33) = 6.332e-02, RAW(x33) = 9.922e-01, RRW(x33) = 1.264e+00
#
# Calculating measures for x34..
# BI(x34) = 6.322e-02, RAW(x34) = 9.921e-01, RRW(x34) = 1.264e+00
#
# Calculating measures for x35..
# BI(x35) = 0.000e+00, RAW(x35) = 1.000e+00, RRW(x35) = 9.995e-01
#
# Calculating measures for x36..
# BI(x36) = 2.025e-04, RAW(x36) = 9.997e-01, RRW(x36) = 1.001e+00
#
# Calculating measures for x37..
# BI(x37) = 7.911e-01, RAW(x37) = 8.981e-01, RRW(x37) = 4.298e+00
#
# Calculating measures for x38..
# BI(x38) = 5.170e-05, RAW(x38) = 1.001e+00, RRW(x38) = 1.001e+00
#
# Calculating measures for x39..
# BI(x39) = 7.910e-01, RAW(x39) = 8.985e-01, RRW(x39) = 4.298e+00
#
# Calculating measures for x40..
# BI(x40) = 3.730e-05, RAW(x40) = 9.995e-01, RRW(x40) = 9.997e-01
#
# Calculating measures for x41..
# BI(x41) = 0.000e+00, RAW(x41) = 1.002e+00, RRW(x41) = 1.001e+00
#
# Calculating measures for x42..
# BI(x42) = 1.863e-04, RAW(x42) = 9.999e-01, RRW(x42) = 1.001e+00
#
# Results saved to tsum_res\importance_measures.json

# %% [markdown]
# ## Comparison plot
#
# BI is bounded in $[0, 1]$ while RAW and RRW are ratios that may take large values, so the three measures are shown as separate panels. Each panel ranks the top 10 components by that measure.

# %%
"""
out_path = TSUMPATH / "importance_measures.json"
with open(out_path, "r") as f:
    results_dict = json.load(f)
bi_dict = results_dict["BI"]
raw_dict = results_dict["RAW"]
rrw_dict = results_dict["RRW"]
"""

# %%
n_data_vis = 10  # number of components to visualise per measure
FONT_FAMILY = "Times New Roman"
LABEL_SIZE = 16
TICK_SIZE = 14
TITLE_SIZE = 18

FIGPATH = "figs"
Path(FIGPATH).mkdir(parents=True, exist_ok=True)

mpl.rcParams["font.family"] = FONT_FAMILY

# (title, dict, descending?)
# RAW = P(S=0|X=1)/P(S=0): lower => more important, so sort ascending.
measures = [
    ("Birnbaum's measure", bi_dict, True),
    ("Risk Achievement Worth", raw_dict, False),
    ("Risk Reduction Worth", rrw_dict, True),
]

fig, axes = plt.subplots(1, 3, figsize=(21, 6))

for ax, (title, mdict, descending) in zip(axes, measures):
    finite_items = [(k, v) for k, v in mdict.items() if np.isfinite(v)]
    sorted_items = sorted(finite_items, key=lambda kv: kv[1], reverse=descending)
    top_items = sorted_items[:n_data_vis]
    keys, values = zip(*top_items)
    keys_rlb = relabel_selected_keys(list(keys), nodes, edges)

    ax.bar(keys_rlb, values)
    ax.set_xlabel("Top 10 components", fontsize=LABEL_SIZE)
    ax.set_ylabel(title, fontsize=LABEL_SIZE)
    ax.tick_params(axis='x', rotation=45, labelsize=TICK_SIZE)
    ax.tick_params(axis='y', labelsize=TICK_SIZE)
    for label in ax.get_xticklabels():
        label.set_horizontalalignment('right')

plt.tight_layout()
out_fig = Path(FIGPATH) / "importance_measures_top10.png"
plt.savefig(out_fig, dpi=300)
plt.show()
