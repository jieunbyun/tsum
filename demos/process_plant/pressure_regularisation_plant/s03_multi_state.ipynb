# %%
from ndtools import staged_max_flow as smf

from pathlib import Path
import json

from tsum import tsum
import torch

# %% [markdown]
# # Multi-state reliability analysis of pressure regularisation plant
#
# This notebook repeats the rule-finding process of `s01_find_rules.ipynb`, but each component now has three states (0, 1, 2) with probabilities (0.03, 0.05, 0.92) and remaining-capacity ratios (0.0, 0.5, 1.0).

# %% [markdown]
# ## Load data

# %%
DATASET = Path(r"data")

nodes = json.loads((DATASET / "nodes.json").read_text(encoding="utf-8"))
edges = json.loads((DATASET / "edges.json").read_text(encoding="utf-8"))
probs_dict = json.loads((DATASET / "probs_multi.json").read_text(encoding="utf-8"))

# %%
def s_fun(comps_st):
    flow, sys_st_str, min_comp_state = smf.sys_fun( comps_st, nodes, edges, probs_dict, target_flow = 90.0 )

    sys_st = 1 if sys_st_str == 's' else 0
    return flow, sys_st, min_comp_state

row_names = list(probs_dict.keys())
n_state = 3  # three states: 0, 1, 2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
probs = [[probs_dict[n][str(s)]['p'] for s in range(n_state)] for n in row_names]
probs = torch.tensor(probs, dtype=torch.float32, device=device)

# %% [markdown]
# ## Get rules for system event

# %%
sys_surv_st = 1

result = tsum.run_rule_extraction_by_mcs(
    # Problem-specific callables / data
    sfun=s_fun,
    probs=probs,
    row_names=row_names,
    n_state=n_state,
    sys_surv_st=sys_surv_st,
    unk_prob_thres = 1e-5,
    output_dir="tsum_res_multi"
)
# Out:
# ---
# Round: 1, Unk. prob.: 1.000e+00
# Surv probs: 0.000e+00, Fail probs: 0.000e+00
# No. of non-dominant rules: 0, Survival rules: 0, Failure rules: 0
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x10': ('<=', 1), 'x40': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [55.0]
# ---
# Round: 2, Unk. prob.: 1.000e+00
# Surv probs: 0.000e+00, Fail probs: 0.000e+00
# No. of non-dominant rules: 1, Survival rules: 0, Failure rules: 1
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 31): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x5': ('>=', 1), 'x6': ('>=', 1), 'x8': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x21': ('>=', 1), 'x22': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x28': ('>=', 1), 'x29': ('>=', 1), 'x31': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# Updated sys_vals: [55.0, 90.0]
# ---
# Round: 3, Unk. prob.: 9.977e-01
# Surv probs: 0.000e+00, Fail probs: 2.350e-03
# No. of non-dominant rules: 2, Survival rules: 1, Failure rules: 1
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 23): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x4': ('>=', 1), 'x6': ('>=', 1), 'x7': ('>=', 1), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x20': ('>=', 1), 'x22': ('>=', 1), 'x23': ('>=', 1), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 4, Unk. prob.: 6.672e-01
# Surv probs: 3.305e-01, Fail probs: 2.290e-03
# No. of non-dominant rules: 3, Survival rules: 2, Failure rules: 1
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'x37': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 5, Unk. prob.: 4.819e-01
# Surv probs: 5.159e-01, Fail probs: 2.200e-03
# No. of non-dominant rules: 4, Survival rules: 2, Failure rules: 2
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 32): {'x1': ('>=', 1), 'x4': ('>=', 1), 'x5': ('>=', 1), 'x6': ('>=', 1), 'x8': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 1), 'x21': ('>=', 1), 'x23': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x28': ('>=', 1), 'x29': ('>=', 1), 'x31': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 6, Unk. prob.: 4.513e-01
# Surv probs: 5.158e-01, Fail probs: 3.288e-02
# No. of non-dominant rules: 5, Survival rules: 3, Failure rules: 2
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 19): {'x1': ('>=', 1), 'x3': ('>=', 2), 'x6': ('>=', 1), 'x7': ('>=', 1), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 2), 'x22': ('>=', 2), 'x25': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 7, Unk. prob.: 4.047e-01
# Surv probs: 5.628e-01, Fail probs: 3.242e-02
# No. of non-dominant rules: 6, Survival rules: 4, Failure rules: 2
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 32): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x4': ('>=', 1), 'x6': ('>=', 1), 'x8': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x20': ('>=', 1), 'x22': ('>=', 1), 'x23': ('>=', 1), 'x25': ('>=', 1), 'x27': ('>=', 1), 'x28': ('>=', 1), 'x29': ('>=', 1), 'x31': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 8, Unk. prob.: 3.750e-01
# Surv probs: 5.915e-01, Fail probs: 3.355e-02
# No. of non-dominant rules: 7, Survival rules: 5, Failure rules: 2
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x11': ('<=', 0), 'x12': ('<=', 1), 'sys': ('<=', 0)}
# Updated sys_vals: [45.0, 55.0, 90.0]
# ---
# Round: 9, Unk. prob.: 3.679e-01
# Surv probs: 6.003e-01, Fail probs: 3.184e-02
# No. of non-dominant rules: 8, Survival rules: 5, Failure rules: 3
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 20): {'x1': ('>=', 1), 'x4': ('>=', 2), 'x6': ('>=', 1), 'x7': ('>=', 1), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 2), 'x23': ('>=', 2), 'x25': ('>=', 1), 'x26': ('>=', 2), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 10, Unk. prob.: 3.650e-01
# Surv probs: 6.006e-01, Fail probs: 3.437e-02
# No. of non-dominant rules: 9, Survival rules: 6, Failure rules: 3
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'x25': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 11, Unk. prob.: 3.481e-01
# Surv probs: 6.168e-01, Fail probs: 3.508e-02
# No. of non-dominant rules: 10, Survival rules: 6, Failure rules: 4
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x5': ('<=', 0), 'x19': ('<=', 1), 'x23': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 12, Unk. prob.: 3.171e-01
# Surv probs: 6.189e-01, Fail probs: 6.403e-02
# No. of non-dominant rules: 11, Survival rules: 6, Failure rules: 5
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 31): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x5': ('>=', 1), 'x7': ('>=', 1), 'x8': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x21': ('>=', 1), 'x22': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x32': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 13, Unk. prob.: 3.217e-01
# Surv probs: 6.136e-01, Fail probs: 6.462e-02
# No. of non-dominant rules: 12, Survival rules: 7, Failure rules: 5
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: -0.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'x17': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [0.0, 45.0, 55.0, 90.0]
# ---
# Round: 14, Unk. prob.: 2.888e-01
# Surv probs: 6.465e-01, Fail probs: 6.475e-02
# No. of non-dominant rules: 13, Survival rules: 7, Failure rules: 6
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x3': ('<=', 0), 'x20': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 15, Unk. prob.: 2.623e-01
# Surv probs: 6.466e-01, Fail probs: 9.113e-02
# No. of non-dominant rules: 14, Survival rules: 7, Failure rules: 7
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x12': ('<=', 1), 'x13': ('<=', 1), 'sys': ('<=', 0)}
# Updated sys_vals: [0.0, 45.0, 55.0, 72.5, 90.0]
# ---
# Round: 16, Unk. prob.: 2.652e-01
# Surv probs: 6.445e-01, Fail probs: 9.032e-02
# No. of non-dominant rules: 15, Survival rules: 7, Failure rules: 8
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x13': ('<=', 1), 'x37': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 17, Unk. prob.: 2.578e-01
# Surv probs: 6.451e-01, Fail probs: 9.706e-02
# No. of non-dominant rules: 16, Survival rules: 7, Failure rules: 9
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x39': ('<=', 1), 'x41': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 18, Unk. prob.: 2.519e-01
# Surv probs: 6.445e-01, Fail probs: 1.036e-01
# No. of non-dominant rules: 17, Survival rules: 7, Failure rules: 10
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: -0.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'x18': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 19, Unk. prob.: 2.474e-01
# Surv probs: 6.467e-01, Fail probs: 1.059e-01
# No. of non-dominant rules: 18, Survival rules: 7, Failure rules: 11
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x39': ('<=', 1), 'x40': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 20, Unk. prob.: 2.201e-01
# Surv probs: 6.434e-01, Fail probs: 1.365e-01
# No. of non-dominant rules: 19, Survival rules: 7, Failure rules: 12
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 30): {'x2': ('>=', 1), 'x4': ('>=', 2), 'x6': ('>=', 1), 'x8': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 2), 'x23': ('>=', 2), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x27': ('>=', 1), 'x28': ('>=', 1), 'x29': ('>=', 1), 'x31': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 21, Unk. prob.: 2.192e-01
# Surv probs: 6.445e-01, Fail probs: 1.363e-01
# No. of non-dominant rules: 20, Survival rules: 8, Failure rules: 12
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 30): {'x1': ('>=', 1), 'x4': ('>=', 2), 'x7': ('>=', 1), 'x8': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 2), 'x23': ('>=', 2), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x27': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x32': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 22, Unk. prob.: 2.157e-01
# Surv probs: 6.490e-01, Fail probs: 1.353e-01
# No. of non-dominant rules: 21, Survival rules: 9, Failure rules: 12
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'x39': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 23, Unk. prob.: 2.130e-01
# Surv probs: 6.501e-01, Fail probs: 1.369e-01
# No. of non-dominant rules: 22, Survival rules: 9, Failure rules: 13
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'x12': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 24, Unk. prob.: 1.881e-01
# Surv probs: 6.510e-01, Fail probs: 1.609e-01
# No. of non-dominant rules: 23, Survival rules: 9, Failure rules: 14
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x3': ('<=', 1), 'x4': ('<=', 0), 'x24': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 25, Unk. prob.: 1.651e-01
# Surv probs: 6.540e-01, Fail probs: 1.809e-01
# No. of non-dominant rules: 24, Survival rules: 9, Failure rules: 15
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 20): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x4': ('>=', 1), 'x6': ('>=', 2), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x20': ('>=', 1), 'x22': ('>=', 1), 'x23': ('>=', 1), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x29': ('>=', 2), 'x33': ('>=', 2), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 26, Unk. prob.: 1.639e-01
# Surv probs: 6.518e-01, Fail probs: 1.843e-01
# No. of non-dominant rules: 25, Survival rules: 10, Failure rules: 15
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 29): {'x1': ('>=', 1), 'x4': ('>=', 1), 'x5': ('>=', 1), 'x6': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 1), 'x21': ('>=', 1), 'x23': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x28': ('>=', 1), 'x29': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x36': ('>=', 2), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 27, Unk. prob.: 1.499e-01
# Surv probs: 6.686e-01, Fail probs: 1.815e-01
# No. of non-dominant rules: 26, Survival rules: 11, Failure rules: 15
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'x10': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 28, Unk. prob.: 1.447e-01
# Surv probs: 6.734e-01, Fail probs: 1.819e-01
# No. of non-dominant rules: 27, Survival rules: 11, Failure rules: 16
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x6': ('<=', 0), 'x30': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 29, Unk. prob.: 1.192e-01
# Surv probs: 6.768e-01, Fail probs: 2.040e-01
# No. of non-dominant rules: 28, Survival rules: 11, Failure rules: 17
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: -0.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'x16': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 30, Unk. prob.: 1.202e-01
# Surv probs: 6.732e-01, Fail probs: 2.066e-01
# No. of non-dominant rules: 29, Survival rules: 11, Failure rules: 18
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x12': ('<=', 1), 'x20': ('<=', 0), 'x24': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 31, Unk. prob.: 9.539e-02
# Surv probs: 6.747e-01, Fail probs: 2.299e-01
# No. of non-dominant rules: 30, Survival rules: 11, Failure rules: 19
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 82.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x10': ('<=', 1), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# Updated sys_vals: [0.0, 45.0, 55.0, 72.5, 82.5, 90.0]
# ---
# Round: 32, Unk. prob.: 9.573e-02
# Surv probs: 6.720e-01, Fail probs: 2.322e-01
# No. of non-dominant rules: 31, Survival rules: 11, Failure rules: 20
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x37': ('<=', 1), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 33, Unk. prob.: 9.368e-02
# Surv probs: 6.745e-01, Fail probs: 2.319e-01
# No. of non-dominant rules: 32, Survival rules: 11, Failure rules: 21
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 82.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x10': ('<=', 1), 'x41': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 34, Unk. prob.: 9.162e-02
# Surv probs: 6.730e-01, Fail probs: 2.354e-01
# No. of non-dominant rules: 33, Survival rules: 11, Failure rules: 22
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x20': ('<=', 0), 'x22': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 35, Unk. prob.: 8.737e-02
# Surv probs: 6.733e-01, Fail probs: 2.393e-01
# No. of non-dominant rules: 34, Survival rules: 11, Failure rules: 23
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 29): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x4': ('>=', 1), 'x6': ('>=', 1), 'x8': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x20': ('>=', 1), 'x22': ('>=', 1), 'x23': ('>=', 1), 'x25': ('>=', 1), 'x27': ('>=', 1), 'x28': ('>=', 1), 'x29': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 2), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 36, Unk. prob.: 8.670e-02
# Surv probs: 6.740e-01, Fail probs: 2.393e-01
# No. of non-dominant rules: 35, Survival rules: 12, Failure rules: 23
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 20): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x4': ('>=', 1), 'x7': ('>=', 2), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x20': ('>=', 1), 'x22': ('>=', 1), 'x23': ('>=', 1), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x30': ('>=', 2), 'x34': ('>=', 2), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 37, Unk. prob.: 8.024e-02
# Surv probs: 6.812e-01, Fail probs: 2.385e-01
# No. of non-dominant rules: 36, Survival rules: 13, Failure rules: 23
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 28): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x5': ('>=', 1), 'x7': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x21': ('>=', 1), 'x22': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x34': ('>=', 1), 'x36': ('>=', 2), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 38, Unk. prob.: 6.667e-02
# Surv probs: 6.944e-01, Fail probs: 2.390e-01
# No. of non-dominant rules: 37, Survival rules: 14, Failure rules: 23
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x12': ('<=', 1), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 39, Unk. prob.: 6.249e-02
# Surv probs: 6.961e-01, Fail probs: 2.414e-01
# No. of non-dominant rules: 38, Survival rules: 14, Failure rules: 24
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x6': ('<=', 0), 'x30': ('<=', 1), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 40, Unk. prob.: 6.104e-02
# Surv probs: 6.978e-01, Fail probs: 2.412e-01
# No. of non-dominant rules: 39, Survival rules: 14, Failure rules: 25
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 16): {'x1': ('>=', 1), 'x3': ('>=', 2), 'x6': ('>=', 2), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 2), 'x22': ('>=', 2), 'x25': ('>=', 1), 'x29': ('>=', 2), 'x33': ('>=', 2), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 41, Unk. prob.: 6.055e-02
# Surv probs: 6.971e-01, Fail probs: 2.423e-01
# No. of non-dominant rules: 40, Survival rules: 15, Failure rules: 25
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x37': ('<=', 1), 'x41': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 42, Unk. prob.: 5.894e-02
# Surv probs: 6.992e-01, Fail probs: 2.418e-01
# No. of non-dominant rules: 41, Survival rules: 15, Failure rules: 26
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 27): {'x2': ('>=', 1), 'x4': ('>=', 2), 'x7': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 2), 'x23': ('>=', 2), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x27': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x34': ('>=', 1), 'x36': ('>=', 2), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 43, Unk. prob.: 5.733e-02
# Surv probs: 6.967e-01, Fail probs: 2.460e-01
# No. of non-dominant rules: 42, Survival rules: 16, Failure rules: 26
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x29': ('<=', 0), 'x30': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 44, Unk. prob.: 5.485e-02
# Surv probs: 7.011e-01, Fail probs: 2.440e-01
# No. of non-dominant rules: 43, Survival rules: 16, Failure rules: 27
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x22': ('<=', 0), 'x26': ('<=', 1), 'x40': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 45, Unk. prob.: 5.452e-02
# Surv probs: 6.993e-01, Fail probs: 2.462e-01
# No. of non-dominant rules: 44, Survival rules: 16, Failure rules: 28
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x12': ('<=', 1), 'x41': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 46, Unk. prob.: 5.579e-02
# Surv probs: 6.984e-01, Fail probs: 2.458e-01
# No. of non-dominant rules: 45, Survival rules: 16, Failure rules: 29
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 82.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x10': ('<=', 1), 'x13': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 47, Unk. prob.: 5.463e-02
# Surv probs: 6.957e-01, Fail probs: 2.497e-01
# No. of non-dominant rules: 46, Survival rules: 16, Failure rules: 30
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 20): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x4': ('>=', 1), 'x7': ('>=', 2), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x20': ('>=', 1), 'x22': ('>=', 1), 'x23': ('>=', 1), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x30': ('>=', 2), 'x34': ('>=', 2), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 48, Unk. prob.: 4.976e-02
# Surv probs: 6.987e-01, Fail probs: 2.515e-01
# No. of non-dominant rules: 47, Survival rules: 17, Failure rules: 30
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x22': ('<=', 1), 'x26': ('<=', 0), 'x41': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 49, Unk. prob.: 4.992e-02
# Surv probs: 6.982e-01, Fail probs: 2.519e-01
# No. of non-dominant rules: 48, Survival rules: 17, Failure rules: 31
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x22': ('<=', 0), 'x26': ('<=', 1), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 50, Unk. prob.: 5.021e-02
# Surv probs: 6.995e-01, Fail probs: 2.503e-01
# No. of non-dominant rules: 49, Survival rules: 17, Failure rules: 32
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x10': ('<=', 1), 'x28': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 51, Unk. prob.: 4.961e-02
# Surv probs: 6.965e-01, Fail probs: 2.539e-01
# No. of non-dominant rules: 50, Survival rules: 17, Failure rules: 33
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x37': ('<=', 1), 'x40': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 52, Unk. prob.: 4.821e-02
# Surv probs: 7.008e-01, Fail probs: 2.510e-01
# No. of non-dominant rules: 51, Survival rules: 17, Failure rules: 34
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x11': ('<=', 0), 'x39': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 53, Unk. prob.: 4.731e-02
# Surv probs: 6.999e-01, Fail probs: 2.528e-01
# No. of non-dominant rules: 52, Survival rules: 17, Failure rules: 35
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 29): {'x1': ('>=', 1), 'x4': ('>=', 1), 'x5': ('>=', 1), 'x6': ('>=', 1), 'x8': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 1), 'x21': ('>=', 1), 'x23': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x28': ('>=', 1), 'x29': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 2), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 54, Unk. prob.: 4.700e-02
# Surv probs: 7.000e-01, Fail probs: 2.530e-01
# No. of non-dominant rules: 53, Survival rules: 18, Failure rules: 35
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x4': ('<=', 0), 'x22': ('<=', 1), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 55, Unk. prob.: 4.449e-02
# Surv probs: 6.974e-01, Fail probs: 2.581e-01
# No. of non-dominant rules: 54, Survival rules: 18, Failure rules: 36
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x28': ('<=', 0), 'x29': ('<=', 1), 'x30': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 56, Unk. prob.: 4.535e-02
# Surv probs: 7.029e-01, Fail probs: 2.517e-01
# No. of non-dominant rules: 55, Survival rules: 18, Failure rules: 37
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 28): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x5': ('>=', 1), 'x6': ('>=', 1), 'x8': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x21': ('>=', 1), 'x22': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x28': ('>=', 1), 'x29': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 2), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 57, Unk. prob.: 4.533e-02
# Surv probs: 7.031e-01, Fail probs: 2.515e-01
# No. of non-dominant rules: 56, Survival rules: 19, Failure rules: 37
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 82.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x9': ('<=', 0), 'x10': ('<=', 1), 'x35': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 58, Unk. prob.: 4.465e-02
# Surv probs: 7.003e-01, Fail probs: 2.550e-01
# No. of non-dominant rules: 57, Survival rules: 19, Failure rules: 38
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 17): {'x1': ('>=', 1), 'x4': ('>=', 2), 'x7': ('>=', 2), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 2), 'x23': ('>=', 2), 'x25': ('>=', 1), 'x26': ('>=', 2), 'x30': ('>=', 2), 'x34': ('>=', 2), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 59, Unk. prob.: 4.348e-02
# Surv probs: 7.032e-01, Fail probs: 2.533e-01
# No. of non-dominant rules: 58, Survival rules: 20, Failure rules: 38
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x4': ('<=', 0), 'x19': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 60, Unk. prob.: 4.301e-02
# Surv probs: 7.049e-01, Fail probs: 2.521e-01
# No. of non-dominant rules: 59, Survival rules: 20, Failure rules: 39
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x39': ('<=', 1), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 61, Unk. prob.: 4.255e-02
# Surv probs: 7.022e-01, Fail probs: 2.553e-01
# No. of non-dominant rules: 60, Survival rules: 20, Failure rules: 40
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x11': ('<=', 0), 'x22': ('<=', 0), 'x23': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 62, Unk. prob.: 4.028e-02
# Surv probs: 7.045e-01, Fail probs: 2.552e-01
# No. of non-dominant rules: 61, Survival rules: 20, Failure rules: 41
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x22': ('<=', 0), 'x26': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 63, Unk. prob.: 4.035e-02
# Surv probs: 7.033e-01, Fail probs: 2.563e-01
# No. of non-dominant rules: 62, Survival rules: 20, Failure rules: 42
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 17): {'x1': ('>=', 1), 'x4': ('>=', 2), 'x6': ('>=', 2), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 2), 'x23': ('>=', 2), 'x25': ('>=', 1), 'x26': ('>=', 2), 'x29': ('>=', 2), 'x33': ('>=', 2), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 64, Unk. prob.: 3.933e-02
# Surv probs: 7.043e-01, Fail probs: 2.563e-01
# No. of non-dominant rules: 63, Survival rules: 21, Failure rules: 42
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x22': ('<=', 1), 'x26': ('<=', 0), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 65, Unk. prob.: 3.752e-02
# Surv probs: 7.059e-01, Fail probs: 2.566e-01
# No. of non-dominant rules: 64, Survival rules: 21, Failure rules: 43
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x30': ('<=', 0), 'x33': ('<=', 1), 'x40': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 66, Unk. prob.: 3.901e-02
# Surv probs: 7.032e-01, Fail probs: 2.578e-01
# No. of non-dominant rules: 65, Survival rules: 21, Failure rules: 44
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x7': ('<=', 1), 'x28': ('<=', 0), 'x33': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 67, Unk. prob.: 3.795e-02
# Surv probs: 7.048e-01, Fail probs: 2.572e-01
# No. of non-dominant rules: 66, Survival rules: 21, Failure rules: 45
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x6': ('<=', 0), 'x34': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 68, Unk. prob.: 3.800e-02
# Surv probs: 7.031e-01, Fail probs: 2.589e-01
# No. of non-dominant rules: 67, Survival rules: 21, Failure rules: 46
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x7': ('<=', 0), 'x33': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 69, Unk. prob.: 3.788e-02
# Surv probs: 7.065e-01, Fail probs: 2.557e-01
# No. of non-dominant rules: 68, Survival rules: 21, Failure rules: 47
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 16): {'x2': ('>=', 1), 'x3': ('>=', 2), 'x7': ('>=', 2), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 2), 'x22': ('>=', 2), 'x25': ('>=', 1), 'x30': ('>=', 2), 'x34': ('>=', 2), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 70, Unk. prob.: 3.687e-02
# Surv probs: 7.051e-01, Fail probs: 2.581e-01
# No. of non-dominant rules: 69, Survival rules: 22, Failure rules: 47
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x7': ('<=', 0), 'x29': ('<=', 1), 'x41': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 71, Unk. prob.: 3.372e-02
# Surv probs: 7.047e-01, Fail probs: 2.616e-01
# No. of non-dominant rules: 70, Survival rules: 22, Failure rules: 48
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 20): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x4': ('>=', 1), 'x6': ('>=', 2), 'x10': ('>=', 2), 'x12': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x20': ('>=', 1), 'x22': ('>=', 1), 'x23': ('>=', 1), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x29': ('>=', 2), 'x33': ('>=', 2), 'x37': ('>=', 2), 'x39': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 72, Unk. prob.: 3.484e-02
# Surv probs: 7.083e-01, Fail probs: 2.569e-01
# No. of non-dominant rules: 71, Survival rules: 23, Failure rules: 48
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x12': ('<=', 1), 'x28': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 73, Unk. prob.: 3.360e-02
# Surv probs: 7.067e-01, Fail probs: 2.597e-01
# No. of non-dominant rules: 72, Survival rules: 23, Failure rules: 49
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x19': ('<=', 0), 'x26': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 74, Unk. prob.: 3.218e-02
# Surv probs: 7.103e-01, Fail probs: 2.576e-01
# No. of non-dominant rules: 73, Survival rules: 23, Failure rules: 50
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x3': ('<=', 0), 'x23': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 75, Unk. prob.: 3.274e-02
# Surv probs: 7.088e-01, Fail probs: 2.584e-01
# No. of non-dominant rules: 74, Survival rules: 23, Failure rules: 51
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: -0.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x1': ('<=', 0), 'x2': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 76, Unk. prob.: 3.101e-02
# Surv probs: 7.075e-01, Fail probs: 2.615e-01
# No. of non-dominant rules: 75, Survival rules: 23, Failure rules: 52
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x28': ('<=', 0), 'x39': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 77, Unk. prob.: 3.094e-02
# Surv probs: 7.058e-01, Fail probs: 2.633e-01
# No. of non-dominant rules: 76, Survival rules: 23, Failure rules: 53
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 2): {'x13': ('<=', 1), 'x39': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 78, Unk. prob.: 3.036e-02
# Surv probs: 7.068e-01, Fail probs: 2.628e-01
# No. of non-dominant rules: 77, Survival rules: 23, Failure rules: 54
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x4': ('<=', 0), 'x19': ('<=', 1), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 79, Unk. prob.: 2.772e-02
# Surv probs: 7.059e-01, Fail probs: 2.664e-01
# No. of non-dominant rules: 78, Survival rules: 23, Failure rules: 55
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x21': ('<=', 0), 'x23': ('<=', 0), 'x37': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 80, Unk. prob.: 2.798e-02
# Surv probs: 7.102e-01, Fail probs: 2.618e-01
# No. of non-dominant rules: 79, Survival rules: 23, Failure rules: 56
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x7': ('<=', 0), 'x13': ('<=', 1), 'x29': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 81, Unk. prob.: 2.774e-02
# Surv probs: 7.080e-01, Fail probs: 2.642e-01
# No. of non-dominant rules: 80, Survival rules: 23, Failure rules: 57
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x7': ('<=', 1), 'x29': ('<=', 0), 'x41': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 82, Unk. prob.: 2.817e-02
# Surv probs: 7.097e-01, Fail probs: 2.622e-01
# No. of non-dominant rules: 81, Survival rules: 23, Failure rules: 58
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x19': ('<=', 0), 'x26': ('<=', 1), 'x41': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 83, Unk. prob.: 2.802e-02
# Surv probs: 7.070e-01, Fail probs: 2.650e-01
# No. of non-dominant rules: 82, Survival rules: 23, Failure rules: 59
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x19': ('<=', 0), 'x20': ('<=', 1), 'x21': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 84, Unk. prob.: 2.717e-02
# Surv probs: 7.078e-01, Fail probs: 2.650e-01
# No. of non-dominant rules: 83, Survival rules: 23, Failure rules: 60
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x11': ('<=', 0), 'x29': ('<=', 0), 'x34': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 85, Unk. prob.: 2.735e-02
# Surv probs: 7.083e-01, Fail probs: 2.643e-01
# No. of non-dominant rules: 84, Survival rules: 23, Failure rules: 61
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x9': ('<=', 0), 'x12': ('<=', 1), 'x35': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 86, Unk. prob.: 2.740e-02
# Surv probs: 7.076e-01, Fail probs: 2.650e-01
# No. of non-dominant rules: 85, Survival rules: 23, Failure rules: 62
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x22': ('<=', 1), 'x23': ('<=', 0), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 87, Unk. prob.: 2.766e-02
# Surv probs: 7.079e-01, Fail probs: 2.645e-01
# No. of non-dominant rules: 86, Survival rules: 23, Failure rules: 63
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: -0.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x14': ('<=', 0), 'x15': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 88, Unk. prob.: 2.713e-02
# Surv probs: 7.092e-01, Fail probs: 2.636e-01
# No. of non-dominant rules: 87, Survival rules: 23, Failure rules: 64
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'x11': ('<=', 0), 'x30': ('<=', 1), 'x33': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 89, Unk. prob.: 2.650e-02
# Surv probs: 7.068e-01, Fail probs: 2.667e-01
# No. of non-dominant rules: 88, Survival rules: 23, Failure rules: 65
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 29): {'x1': ('>=', 1), 'x4': ('>=', 1), 'x5': ('>=', 1), 'x7': ('>=', 1), 'x8': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x20': ('>=', 1), 'x21': ('>=', 1), 'x23': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x26': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 2), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 90, Unk. prob.: 2.708e-02
# Surv probs: 7.088e-01, Fail probs: 2.641e-01
# No. of non-dominant rules: 89, Survival rules: 24, Failure rules: 65
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x3': ('<=', 1), 'x26': ('<=', 0), 'x41': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 91, Unk. prob.: 2.678e-02
# Surv probs: 7.070e-01, Fail probs: 2.662e-01
# No. of non-dominant rules: 90, Survival rules: 24, Failure rules: 66
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 29): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x4': ('>=', 1), 'x7': ('>=', 1), 'x8': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x14': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x20': ('>=', 1), 'x22': ('>=', 1), 'x23': ('>=', 1), 'x25': ('>=', 1), 'x27': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 2), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 92, Unk. prob.: 2.445e-02
# Surv probs: 7.086e-01, Fail probs: 2.670e-01
# No. of non-dominant rules: 91, Survival rules: 25, Failure rules: 66
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x11': ('<=', 0), 'x37': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 93, Unk. prob.: 2.552e-02
# Surv probs: 7.084e-01, Fail probs: 2.661e-01
# No. of non-dominant rules: 92, Survival rules: 25, Failure rules: 67
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 55.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'x30': ('<=', 0), 'x33': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 94, Unk. prob.: 2.467e-02
# Surv probs: 7.092e-01, Fail probs: 2.661e-01
# No. of non-dominant rules: 93, Survival rules: 25, Failure rules: 68
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 3): {'x7': ('<=', 0), 'x29': ('<=', 1), 'x42': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 95, Unk. prob.: 2.378e-02
# Surv probs: 7.101e-01, Fail probs: 2.661e-01
# No. of non-dominant rules: 94, Survival rules: 25, Failure rules: 69
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 90.0. Total samples: 100000.
# New rule (No. of conditions: 28): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x5': ('>=', 1), 'x6': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x13': ('>=', 2), 'x15': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x18': ('>=', 1), 'x19': ('>=', 1), 'x21': ('>=', 1), 'x22': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x28': ('>=', 1), 'x29': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x36': ('>=', 2), 'x37': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 2), 'x42': ('>=', 2), 'sys': ('>=', 1)}
# ---
# Round: 96, Unk. prob.: 2.403e-02
# Surv probs: 7.084e-01, Fail probs: 2.676e-01
# No. of non-dominant rules: 95, Survival rules: 26, Failure rules: 69
# Survival sample found from sampling.
# No. of existing rules removed:  0
# ...
# New rule (No. of conditions: 4): {'x7': ('<=', 0), 'x31': ('<=', 0), 'x32': ('<=', 0), 'x33': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1089, Unk. prob.: 1.000e-05
# Surv probs: 7.103e-01, Fail probs: 2.897e-01
# No. of non-dominant rules: 1088, Survival rules: 61, Failure rules: 1027
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x8': ('<=', 0), 'x9': ('<=', 0), 'x30': ('<=', 0), 'x33': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1090, Unk. prob.: 4.000e-05
# Surv probs: 7.121e-01, Fail probs: 2.878e-01
# No. of non-dominant rules: 1089, Survival rules: 61, Failure rules: 1028
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x6': ('<=', 0), 'x9': ('<=', 0), 'x31': ('<=', 0), 'x34': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1091, Unk. prob.: 2.000e-05
# Surv probs: 7.119e-01, Fail probs: 2.881e-01
# No. of non-dominant rules: 1090, Survival rules: 61, Failure rules: 1029
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x7': ('<=', 1), 'x8': ('<=', 0), 'x9': ('<=', 0), 'x29': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1092, Unk. prob.: 4.000e-05
# Surv probs: 7.115e-01, Fail probs: 2.885e-01
# No. of non-dominant rules: 1091, Survival rules: 61, Failure rules: 1030
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 200000.
# New rule (No. of conditions: 4): {'x4': ('<=', 0), 'x21': ('<=', 0), 'x29': ('<=', 1), 'x34': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1093, Unk. prob.: 2.000e-05
# Surv probs: 7.110e-01, Fail probs: 2.890e-01
# No. of non-dominant rules: 1092, Survival rules: 61, Failure rules: 1031
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 200000.
# New rule (No. of conditions: 4): {'x21': ('<=', 0), 'x23': ('<=', 0), 'x33': ('<=', 0), 'x34': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1094, Unk. prob.: 1.000e-05
# Surv probs: 7.131e-01, Fail probs: 2.869e-01
# No. of non-dominant rules: 1093, Survival rules: 61, Failure rules: 1032
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x19': ('<=', 1), 'x20': ('<=', 0), 'x31': ('<=', 0), 'x32': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1095, Unk. prob.: 4.000e-05
# Surv probs: 7.107e-01, Fail probs: 2.893e-01
# No. of non-dominant rules: 1094, Survival rules: 61, Failure rules: 1033
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x7': ('<=', 0), 'x20': ('<=', 0), 'x21': ('<=', 0), 'x29': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1096, Unk. prob.: 6.000e-05
# Surv probs: 7.136e-01, Fail probs: 2.864e-01
# No. of non-dominant rules: 1095, Survival rules: 61, Failure rules: 1034
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x8': ('<=', 0), 'x9': ('<=', 0), 'x19': ('<=', 0), 'x20': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1097, Unk. prob.: 7.000e-05
# Surv probs: 7.129e-01, Fail probs: 2.870e-01
# No. of non-dominant rules: 1096, Survival rules: 61, Failure rules: 1035
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x4': ('<=', 0), 'x5': ('<=', 0), 'x6': ('<=', 0), 'x30': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1098, Unk. prob.: 2.000e-05
# Surv probs: 7.118e-01, Fail probs: 2.882e-01
# No. of non-dominant rules: 1097, Survival rules: 61, Failure rules: 1036
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x8': ('<=', 0), 'x9': ('<=', 0), 'x20': ('<=', 1), 'x22': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1099, Unk. prob.: 1.000e-05
# Surv probs: 7.122e-01, Fail probs: 2.878e-01
# No. of non-dominant rules: 1098, Survival rules: 61, Failure rules: 1037
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x4': ('<=', 0), 'x24': ('<=', 0), 'x30': ('<=', 1), 'x33': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1100, Unk. prob.: 3.000e-05
# Surv probs: 7.129e-01, Fail probs: 2.871e-01
# No. of non-dominant rules: 1099, Survival rules: 61, Failure rules: 1038
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 200000.
# New rule (No. of conditions: 4): {'x5': ('<=', 0), 'x27': ('<=', 0), 'x29': ('<=', 0), 'x30': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1101, Unk. prob.: 5.000e-06
# Surv probs: 7.111e-01, Fail probs: 2.889e-01
# No. of non-dominant rules: 1100, Survival rules: 61, Failure rules: 1039
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x6': ('<=', 0), 'x23': ('<=', 0), 'x24': ('<=', 0), 'x30': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1102, Unk. prob.: 3.000e-05
# Surv probs: 7.121e-01, Fail probs: 2.879e-01
# No. of non-dominant rules: 1101, Survival rules: 61, Failure rules: 1040
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x7': ('<=', 1), 'x8': ('<=', 0), 'x9': ('<=', 0), 'x33': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1103, Unk. prob.: 4.000e-05
# Surv probs: 7.120e-01, Fail probs: 2.880e-01
# No. of non-dominant rules: 1102, Survival rules: 61, Failure rules: 1041
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 200000.
# New rule (No. of conditions: 4): {'x6': ('<=', 1), 'x7': ('<=', 0), 'x8': ('<=', 0), 'x9': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1104, Unk. prob.: 3.000e-05
# Surv probs: 7.124e-01, Fail probs: 2.876e-01
# No. of non-dominant rules: 1103, Survival rules: 61, Failure rules: 1042
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x19': ('<=', 1), 'x23': ('<=', 0), 'x31': ('<=', 0), 'x32': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1105, Unk. prob.: 3.000e-05
# Surv probs: 7.119e-01, Fail probs: 2.881e-01
# No. of non-dominant rules: 1104, Survival rules: 61, Failure rules: 1043
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 4): {'x29': ('<=', 1), 'x34': ('<=', 0), 'x35': ('<=', 0), 'x36': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1106, Unk. prob.: 3.000e-05
# Surv probs: 7.132e-01, Fail probs: 2.868e-01
# No. of non-dominant rules: 1105, Survival rules: 61, Failure rules: 1044
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x3': ('<=', 0), 'x20': ('<=', 1), 'x31': ('<=', 0), 'x32': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1107, Unk. prob.: 1.000e-05
# Surv probs: 7.095e-01, Fail probs: 2.905e-01
# No. of non-dominant rules: 1106, Survival rules: 61, Failure rules: 1045
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x7': ('<=', 1), 'x29': ('<=', 0), 'x31': ('<=', 0), 'x32': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1108, Unk. prob.: 1.000e-05
# Surv probs: 7.105e-01, Fail probs: 2.895e-01
# No. of non-dominant rules: 1107, Survival rules: 61, Failure rules: 1046
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 200000.
# New rule (No. of conditions: 4): {'x6': ('<=', 0), 'x20': ('<=', 0), 'x24': ('<=', 0), 'x30': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1109, Unk. prob.: 1.000e-05
# Surv probs: 7.114e-01, Fail probs: 2.886e-01
# No. of non-dominant rules: 1108, Survival rules: 61, Failure rules: 1047
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x4': ('<=', 0), 'x24': ('<=', 0), 'x29': ('<=', 1), 'x30': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1110, Unk. prob.: 1.000e-05
# Surv probs: 7.094e-01, Fail probs: 2.906e-01
# No. of non-dominant rules: 1109, Survival rules: 61, Failure rules: 1048
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x4': ('<=', 0), 'x5': ('<=', 0), 'x29': ('<=', 0), 'x30': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1111, Unk. prob.: 1.000e-05
# Surv probs: 7.123e-01, Fail probs: 2.877e-01
# No. of non-dominant rules: 1110, Survival rules: 61, Failure rules: 1049
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x5': ('<=', 0), 'x23': ('<=', 0), 'x29': ('<=', 1), 'x30': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1112, Unk. prob.: 3.000e-05
# Surv probs: 7.115e-01, Fail probs: 2.884e-01
# No. of non-dominant rules: 1111, Survival rules: 61, Failure rules: 1050
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x3': ('<=', 0), 'x9': ('<=', 0), 'x23': ('<=', 1), 'x31': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1113, Unk. prob.: 1.000e-05
# Surv probs: 7.112e-01, Fail probs: 2.888e-01
# No. of non-dominant rules: 1112, Survival rules: 61, Failure rules: 1051
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x6': ('<=', 1), 'x23': ('<=', 0), 'x24': ('<=', 0), 'x34': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1114, Unk. prob.: 2.000e-05
# Surv probs: 7.109e-01, Fail probs: 2.891e-01
# No. of non-dominant rules: 1113, Survival rules: 61, Failure rules: 1052
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x3': ('<=', 1), 'x9': ('<=', 0), 'x26': ('<=', 0), 'x31': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1115, Unk. prob.: 5.000e-05
# Surv probs: 7.124e-01, Fail probs: 2.876e-01
# No. of non-dominant rules: 1114, Survival rules: 61, Failure rules: 1053
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x7': ('<=', 0), 'x9': ('<=', 0), 'x31': ('<=', 0), 'x33': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1116, Unk. prob.: 2.000e-05
# Surv probs: 7.095e-01, Fail probs: 2.905e-01
# No. of non-dominant rules: 1115, Survival rules: 61, Failure rules: 1054
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 300000.
# New rule (No. of conditions: 4): {'x7': ('<=', 0), 'x20': ('<=', 0), 'x24': ('<=', 0), 'x29': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1117, Unk. prob.: 6.667e-06
# Surv probs: 7.111e-01, Fail probs: 2.889e-01
# No. of non-dominant rules: 1116, Survival rules: 61, Failure rules: 1055
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x20': ('<=', 0), 'x24': ('<=', 0), 'x29': ('<=', 0), 'x30': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1118, Unk. prob.: 1.000e-05
# Surv probs: 7.127e-01, Fail probs: 2.872e-01
# No. of non-dominant rules: 1117, Survival rules: 61, Failure rules: 1056
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 200000.
# New rule (No. of conditions: 4): {'x20': ('<=', 0), 'x21': ('<=', 0), 'x30': ('<=', 0), 'x33': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1119, Unk. prob.: 2.000e-05
# Surv probs: 7.113e-01, Fail probs: 2.887e-01
# No. of non-dominant rules: 1118, Survival rules: 61, Failure rules: 1057
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x8': ('<=', 0), 'x9': ('<=', 0), 'x22': ('<=', 0), 'x26': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1120, Unk. prob.: 1.000e-05
# Surv probs: 7.122e-01, Fail probs: 2.878e-01
# No. of non-dominant rules: 1119, Survival rules: 61, Failure rules: 1058
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 72.5. Total samples: 100000.
# New rule (No. of conditions: 4): {'x19': ('<=', 0), 'x23': ('<=', 1), 'x35': ('<=', 1), 'x36': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1121, Unk. prob.: 4.000e-05
# Surv probs: 7.111e-01, Fail probs: 2.889e-01
# No. of non-dominant rules: 1120, Survival rules: 61, Failure rules: 1059
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x3': ('<=', 1), 'x8': ('<=', 0), 'x9': ('<=', 0), 'x26': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1122, Unk. prob.: 3.000e-05
# Surv probs: 7.119e-01, Fail probs: 2.880e-01
# No. of non-dominant rules: 1121, Survival rules: 61, Failure rules: 1060
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x6': ('<=', 0), 'x21': ('<=', 0), 'x27': ('<=', 0), 'x30': ('<=', 1), 'sys': ('<=', 0)}
# ---
# Round: 1123, Unk. prob.: 1.000e-05
# Surv probs: 7.100e-01, Fail probs: 2.900e-01
# No. of non-dominant rules: 1122, Survival rules: 61, Failure rules: 1061
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x5': ('<=', 0), 'x6': ('<=', 1), 'x7': ('<=', 0), 'x27': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1124, Unk. prob.: 3.000e-05
# Surv probs: 7.109e-01, Fail probs: 2.891e-01
# No. of non-dominant rules: 1123, Survival rules: 61, Failure rules: 1062
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'x5': ('<=', 0), 'x7': ('<=', 1), 'x23': ('<=', 0), 'x29': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 1125, Unk. prob.: 2.000e-05
# Surv probs: 7.088e-01, Fail probs: 2.912e-01
# No. of non-dominant rules: 1124, Survival rules: 61, Failure rules: 1063
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 45.0. Total samples: 400000.
# New rule (No. of conditions: 4): {'x7': ('<=', 0), 'x20': ('<=', 0), 'x24': ('<=', 0), 'x33': ('<=', 1), 'sys': ('<=', 0)}
# ---
# [Final results] Probs: 'surv':  7.111e-01, 'fail':  2.889e-01, 'unkn':  1.510e-05
