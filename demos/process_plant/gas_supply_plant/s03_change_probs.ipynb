# %%
import json
import random
from pathlib import Path
from typing import Iterable, Dict, Union

import torch
from tsum import tsum
from ndtools import staged_max_flow as smf

import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Randomly generate probabilities

# %%
def rewrite_probs_json(
    in_path: Union[str, Path],
    out_path: Union[str, Path],
    *,
    low: float = 0.01,
    high: float = 0.1,
    seed: int | None = None,
) -> dict:
    """
    Load an existing probs.json and replace:
      - probs[x]["0"]["p"] ~ Uniform(low, high)
      - probs[x]["1"]["p"] = 1 - probs[x]["0"]["p"]

    All other fields and schema are preserved.
    """

    if seed is not None:
        random.seed(seed)

    in_path = Path(in_path)
    out_path = Path(out_path)

    with in_path.open("r", encoding="utf-8") as f:
        probs = json.load(f)

    for x, states in probs.items():
        if "0" not in states or "1" not in states:
            raise KeyError(f"{x} does not have states '0' and '1'")

        p0 = random.uniform(low, high)
        p1 = 1.0 - p0

        states["0"]["p"] = p0
        states["1"]["p"] = p1

    out_path.parent.mkdir(parents=True, exist_ok=True)
    with out_path.open("w", encoding="utf-8") as f:
        json.dump(probs, f, indent=4)

    return probs

# %%
DATASET = Path(r"data") 

rewrite_probs_json(
    in_path=DATASET / "probs.json",
    out_path=DATASET / "probs_random.json",
    low=0.01,
    high=0.1,
    seed=42,
)
# Out:
# {'x1': {'0': {'p': 0.06754841186120954, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9324515881387905, 'remaining_capacity_ratio': 1.0}},
#  'x2': {'0': {'p': 0.012250967970040025, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.98774903202996, 'remaining_capacity_ratio': 1.0}},
#  'x3': {'0': {'p': 0.03475263865322074, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9652473613467792, 'remaining_capacity_ratio': 1.0}},
#  'x4': {'0': {'p': 0.03008896643339405, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9699110335666059, 'remaining_capacity_ratio': 1.0}},
#  'x5': {'0': {'p': 0.07628240927476111, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9237175907252388, 'remaining_capacity_ratio': 1.0}},
#  'x6': {'0': {'p': 0.07090295386806203, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.929097046131938, 'remaining_capacity_ratio': 1.0}},
#  'x7': {'0': {'p': 0.09029616109343609, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9097038389065639, 'remaining_capacity_ratio': 1.0}},
#  'x8': {'0': {'p': 0.017824494936647457, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9821755050633525, 'remaining_capacity_ratio': 1.0}},
#  'x9': {'0': {'p': 0.04797296377167434, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9520270362283256, 'remaining_capacity_ratio': 1.0}},
#  'x10': {'0': {'p': 0.01268174974942633, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9873182502505736, 'remaining_capacity_ratio': 1.0}},
#  'x11': {'0': {'p': 0.029677417732324303, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9703225822676756, 'remaining_capacity_ratio': 1.0}},
#  'x12': {'0': {'p': 0.055481975929302624, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9445180240706974, 'remaining_capacity_ratio': 1.0}},
#  'x13': {'0': {'p': 0.012388237271547727, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9876117627284523, 'remaining_capacity_ratio': 1.0}},
#  'x14': {'0': {'p': 0.027895388561798365, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9721046114382016, 'remaining_capacity_ratio': 1.0}},
#  'x15': {'0': {'p': 0.0684895994001571, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9315104005998429, 'remaining_capacity_ratio': 1.0}},
#  'x16': {'0': {'p': 0.05904473325428951, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9409552667457105, 'remaining_capacity_ratio': 1.0}},
#  'x17': {'0': {'p': 0.029839655983662706, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9701603440163373, 'remaining_capacity_ratio': 1.0}},
#  'x18': {'0': {'p': 0.06303391154883178, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9369660884511682, 'remaining_capacity_ratio': 1.0}},
#  'x19': {'0': {'p': 0.0828487411010044, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9171512588989956, 'remaining_capacity_ratio': 1.0}},
#  'x20': {'0': {'p': 0.010584888371025492, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9894151116289746, 'remaining_capacity_ratio': 1.0}},
#  'x21': {'0': {'p': 0.08252373266495272, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9174762673350473, 'remaining_capacity_ratio': 1.0}},
#  'x22': {'0': {'p': 0.07283254554894042, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9271674544510595, 'remaining_capacity_ratio': 1.0}},
#  'x23': {'0': {'p': 0.040622546486619275, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9593774535133808, 'remaining_capacity_ratio': 1.0}},
#  'x24': {'0': {'p': 0.023993154983060344, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9760068450169397, 'remaining_capacity_ratio': 1.0}},
#  'x25': {'0': {'p': 0.09614917649861031, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9038508235013897, 'remaining_capacity_ratio': 1.0}},
#  'x26': {'0': {'p': 0.040293509060136415, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9597064909398636, 'remaining_capacity_ratio': 1.0}},
#  'x27': {'0': {'p': 0.018347125904213314, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9816528740957867, 'remaining_capacity_ratio': 1.0}},
#  'x28': {'0': {'p': 0.01870447391501176, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9812955260849883, 'remaining_capacity_ratio': 1.0}},
#  'x29': {'0': {'p': 0.08627449297127139, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9137255070287286, 'remaining_capacity_ratio': 1.0}},
#  'x30': {'0': {'p': 0.0643353428230202, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9356646571769798, 'remaining_capacity_ratio': 1.0}},
#  'x31': {'0': {'p': 0.08264154459469422, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9173584554053058, 'remaining_capacity_ratio': 1.0}},
#  'x32': {'0': {'p': 0.07567586080244361, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9243241391975564, 'remaining_capacity_ratio': 1.0}},
#  'x33': {'0': {'p': 0.05826052823092307, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9417394717690769, 'remaining_capacity_ratio': 1.0}},
#  'x34': {'0': {'p': 0.09758041875814336, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9024195812418566, 'remaining_capacity_ratio': 1.0}},
#  'x35': {'0': {'p': 0.044068093948751816, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9559319060512482, 'remaining_capacity_ratio': 1.0}},
#  'x36': {'0': {'p': 0.05968365681459044, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9403163431854096, 'remaining_capacity_ratio': 1.0}},
#  'x37': {'0': {'p': 0.08464641978276954, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9153535802172305, 'remaining_capacity_ratio': 1.0}},
#  'x38': {'0': {'p': 0.06566677771278215, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9343332222872178, 'remaining_capacity_ratio': 1.0}},
#  'x39': {'0': {'p': 0.08755362102796996, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9124463789720301, 'remaining_capacity_ratio': 1.0}},
#  'x40': {'0': {'p': 0.061961693073108594, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9380383069268914, 'remaining_capacity_ratio': 1.0}},
#  'x41': {'0': {'p': 0.07341146525934311, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9265885347406568, 'remaining_capacity_ratio': 1.0}},
#  'x42': {'0': {'p': 0.0141241945290096, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9858758054709904, 'remaining_capacity_ratio': 1.0}},
#  'x43': {'0': {'p': 0.03051084480863922, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9694891551913608, 'remaining_capacity_ratio': 1.0}},
#  'x44': {'0': {'p': 0.03604491672418965, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9639550832758104, 'remaining_capacity_ratio': 1.0}},
#  'x45': {'0': {'p': 0.017181277923126476, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9828187220768735, 'remaining_capacity_ratio': 1.0}},
#  'x46': {'0': {'p': 0.030951179772492718, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9690488202275073, 'remaining_capacity_ratio': 1.0}},
#  'x47': {'0': {'p': 0.01909012864687562, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9809098713531244, 'remaining_capacity_ratio': 1.0}},
#  'x48': {'0': {'p': 0.035017624279908295, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9649823757200917, 'remaining_capacity_ratio': 1.0}},
#  'x49': {'0': {'p': 0.06721159998379603, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.932788400016204, 'remaining_capacity_ratio': 1.0}},
#  'x50': {'0': {'p': 0.04283489610730759, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9571651038926924, 'remaining_capacity_ratio': 1.0}},
#  'x51': {'0': {'p': 0.043316287040519444, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9566837129594805, 'remaining_capacity_ratio': 1.0}},
#  'x52': {'0': {'p': 0.028855632769433898, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9711443672305661, 'remaining_capacity_ratio': 1.0}},
#  'x53': {'0': {'p': 0.034028003984420206, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9659719960155798, 'remaining_capacity_ratio': 1.0}},
#  'x54': {'0': {'p': 0.09429891289412447, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9057010871058755, 'remaining_capacity_ratio': 1.0}},
#  'x55': {'0': {'p': 0.06832318467219342, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9316768153278066, 'remaining_capacity_ratio': 1.0}},
#  'x56': {'0': {'p': 0.06482179051002894, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9351782094899711, 'remaining_capacity_ratio': 1.0}},
#  'x57': {'0': {'p': 0.02540247833782873, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9745975216621713, 'remaining_capacity_ratio': 1.0}},
#  'x58': {'0': {'p': 0.07562141181553143, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9243785881844686, 'remaining_capacity_ratio': 1.0}},
#  'x59': {'0': {'p': 0.02470622443857356, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9752937755614265, 'remaining_capacity_ratio': 1.0}},
#  'x60': {'0': {'p': 0.044150989758188305, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9558490102418117, 'remaining_capacity_ratio': 1.0}},
#  'x61': {'0': {'p': 0.09905710155729358, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9009428984427064, 'remaining_capacity_ratio': 1.0}},
#  'x62': {'0': {'p': 0.06759997838686836, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9324000216131316, 'remaining_capacity_ratio': 1.0}},
#  'x63': {'0': {'p': 0.06012547693971817, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9398745230602819, 'remaining_capacity_ratio': 1.0}},
#  'x64': {'0': {'p': 0.07161528258908872, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9283847174109112, 'remaining_capacity_ratio': 1.0}},
#  'x65': {'0': {'p': 0.08585667281708287, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9141433271829171, 'remaining_capacity_ratio': 1.0}},
#  'x66': {'0': {'p': 0.07983999203916203, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.920160007960838, 'remaining_capacity_ratio': 1.0}},
#  'x67': {'0': {'p': 0.0306143264767694, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9693856735232306, 'remaining_capacity_ratio': 1.0}},
#  'x68': {'0': {'p': 0.012889021951363398, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9871109780486366, 'remaining_capacity_ratio': 1.0}},
#  'x69': {'0': {'p': 0.03839077432531738, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9616092256746827, 'remaining_capacity_ratio': 1.0}},
#  'x70': {'0': {'p': 0.03409667883781325, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9659033211621868, 'remaining_capacity_ratio': 1.0}},
#  'x71': {'0': {'p': 0.028988455922769385, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9710115440772307, 'remaining_capacity_ratio': 1.0}},
#  'x72': {'0': {'p': 0.0948618742901549, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9051381257098451, 'remaining_capacity_ratio': 1.0}},
#  'x73': {'0': {'p': 0.0888730863825402, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9111269136174598, 'remaining_capacity_ratio': 1.0}},
#  'x74': {'0': {'p': 0.038321009271863014, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.961678990728137, 'remaining_capacity_ratio': 1.0}},
#  'x75': {'0': {'p': 0.06898947987653921, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9310105201234607, 'remaining_capacity_ratio': 1.0}},
#  'x76': {'0': {'p': 0.045606871095459786, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9543931289045402, 'remaining_capacity_ratio': 1.0}},
#  'x77': {'0': {'p': 0.09230928307664892, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9076907169233511, 'remaining_capacity_ratio': 1.0}},
#  'x78': {'0': {'p': 0.0512966667328659, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9487033332671341, 'remaining_capacity_ratio': 1.0}},
#  'x79': {'0': {'p': 0.03383921498482472, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9661607850151753, 'remaining_capacity_ratio': 1.0}},
#  'x80': {'0': {'p': 0.032196475692458516, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9678035243075415, 'remaining_capacity_ratio': 1.0}},
#  'x81': {'0': {'p': 0.06052313207468358, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9394768679253164, 'remaining_capacity_ratio': 1.0}},
#  'x82': {'0': {'p': 0.033646744767064175, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9663532552329358, 'remaining_capacity_ratio': 1.0}},
#  'x83': {'0': {'p': 0.06261273912011865, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9373872608798813, 'remaining_capacity_ratio': 1.0}},
#  'x84': {'0': {'p': 0.09080405952422294, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.909195940475777, 'remaining_capacity_ratio': 1.0}},
#  'x85': {'0': {'p': 0.04594604546263576, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9540539545373642, 'remaining_capacity_ratio': 1.0}},
#  'x86': {'0': {'p': 0.029738868324155503, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9702611316758445, 'remaining_capacity_ratio': 1.0}},
#  'x87': {'0': {'p': 0.09977838458455993, 'remaining_capacity_ratio': 0.0},
#   '1': {'p': 0.9002216154154401, 'remaining_capacity_ratio': 1.0}}}

# %% [markdown]
# # Load data
#
# Basic information.

# %%
DATASET = Path(r"data") 

nodes = json.loads((DATASET / "nodes.json").read_text(encoding="utf-8"))
edges = json.loads((DATASET / "edges.json").read_text(encoding="utf-8"))
probs_dict = json.loads((DATASET / "probs_random.json").read_text(encoding="utf-8"))

def s_fun(comps_st):
    flow, sys_st_str, min_comp_state = smf.sys_fun( comps_st, nodes, edges, probs_dict, target_flow = 0.5 )

    sys_st = 1 if sys_st_str == 's' else 0
    return flow, sys_st, None

row_names = list(probs_dict.keys())
n_state = 2  # binary states: 0, 1

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
probs = [[probs_dict[n]['0']['p'], probs_dict[n]['1']['p']] for n in row_names]
probs = torch.tensor(probs, dtype=torch.float32, device=device)

# %% [markdown]
# TSUM results

# %%
TSUMPATH = Path("tsum_res")

sys_surv_st = 1  # system survival state

with open(TSUMPATH / "rules_geq_1.json", "r") as f:
    rules_surv = json.load(f)
with open(TSUMPATH / "rules_leq_0.json", "r") as f:
    rules_fail = json.load(f)

rules_mat_surv = torch.load(TSUMPATH / f"rules_geq_{sys_surv_st}.pt", map_location="cpu")
rules_mat_surv = rules_mat_surv.to(device)
rules_mat_fail = torch.load(TSUMPATH / f"rules_leq_{sys_surv_st-1}.pt", map_location="cpu")
rules_mat_fail = rules_mat_fail.to(device)

# %% [markdown]
# Get a little more rules for the changed probabilities.

# %%
result = tsum.run_rule_extraction_by_mcs(
    # Problem-specific callables / data
    sfun=s_fun,
    probs=probs,
    row_names=row_names,
    # Existing rules
    rules_surv = rules_surv,
    rules_fail = rules_fail,
    rules_mat_surv=rules_mat_surv,
    rules_mat_fail=rules_mat_fail,
    # TSUM parameters
    n_state=n_state,
    sys_surv_st=sys_surv_st,
    unk_prob_thres = 1e-6,
    output_dir="tsum_res_random"
)
# Out:
# ---
# Round: 1, Unk. prob.: 1.000e+00
# Surv probs: 0.000e+00, Fail probs: 0.000e+00
# No. of non-dominant rules: 65, Survival rules: 34, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 23): {'x2': ('>=', 1), 'x14': ('>=', 1), 'x17': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x53': ('>=', 1), 'x55': ('>=', 1), 'x57': ('>=', 1), 'x58': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x65': ('>=', 1), 'x66': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# Updated sys_vals: [0.5]
# ---
# Round: 2, Unk. prob.: 2.000e-05
# Surv probs: 6.149e-01, Fail probs: 3.851e-01
# No. of non-dominant rules: 66, Survival rules: 35, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 20): {'x1': ('>=', 1), 'x4': ('>=', 1), 'x18': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x67': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 3, Unk. prob.: 6.000e-05
# Surv probs: 6.124e-01, Fail probs: 3.875e-01
# No. of non-dominant rules: 67, Survival rules: 36, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 17): {'x2': ('>=', 1), 'x16': ('>=', 1), 'x17': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x63': ('>=', 1), 'x64': ('>=', 1), 'x65': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 4, Unk. prob.: 1.000e-05
# Surv probs: 6.141e-01, Fail probs: 3.859e-01
# No. of non-dominant rules: 68, Survival rules: 37, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 22): {'x2': ('>=', 1), 'x10': ('>=', 1), 'x19': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x49': ('>=', 1), 'x50': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x68': ('>=', 1), 'x69': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 5, Unk. prob.: 4.000e-05
# Surv probs: 6.149e-01, Fail probs: 3.851e-01
# No. of non-dominant rules: 69, Survival rules: 38, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 18): {'x2': ('>=', 1), 'x20': ('>=', 1), 'x23': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x68': ('>=', 1), 'x70': ('>=', 1), 'x71': ('>=', 1), 'x73': ('>=', 1), 'x75': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 6, Unk. prob.: 1.000e-05
# Surv probs: 6.140e-01, Fail probs: 3.860e-01
# No. of non-dominant rules: 70, Survival rules: 39, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 19): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x14': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x53': ('>=', 1), 'x55': ('>=', 1), 'x57': ('>=', 1), 'x58': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 7, Unk. prob.: 3.000e-05
# Surv probs: 6.144e-01, Fail probs: 3.856e-01
# No. of non-dominant rules: 71, Survival rules: 40, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 23): {'x1': ('>=', 1), 'x24': ('>=', 1), 'x25': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x68': ('>=', 1), 'x70': ('>=', 1), 'x73': ('>=', 1), 'x76': ('>=', 1), 'x77': ('>=', 1), 'x78': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 8, Unk. prob.: 1.000e-05
# Surv probs: 6.173e-01, Fail probs: 3.827e-01
# No. of non-dominant rules: 72, Survival rules: 41, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 17): {'x2': ('>=', 1), 'x16': ('>=', 1), 'x19': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x63': ('>=', 1), 'x68': ('>=', 1), 'x69': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 9, Unk. prob.: 1.000e-05
# Surv probs: 6.175e-01, Fail probs: 3.825e-01
# No. of non-dominant rules: 73, Survival rules: 42, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 20): {'x2': ('>=', 1), 'x11': ('>=', 1), 'x18': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x52': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x67': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 10, Unk. prob.: 1.000e-05
# Surv probs: 6.144e-01, Fail probs: 3.856e-01
# No. of non-dominant rules: 74, Survival rules: 43, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 19): {'x1': ('>=', 1), 'x10': ('>=', 1), 'x12': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x49': ('>=', 1), 'x50': ('>=', 1), 'x51': ('>=', 1), 'x53': ('>=', 1), 'x54': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 11, Unk. prob.: 2.000e-05
# Surv probs: 6.164e-01, Fail probs: 3.836e-01
# No. of non-dominant rules: 75, Survival rules: 44, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 20): {'x1': ('>=', 1), 'x7': ('>=', 1), 'x11': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x38': ('>=', 1), 'x40': ('>=', 1), 'x42': ('>=', 1), 'x43': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x52': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 12, Unk. prob.: 1.000e-05
# Surv probs: 6.168e-01, Fail probs: 3.831e-01
# No. of non-dominant rules: 76, Survival rules: 45, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 20): {'x2': ('>=', 1), 'x11': ('>=', 1), 'x17': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x52': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x65': ('>=', 1), 'x66': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 13, Unk. prob.: 1.000e-05
# Surv probs: 6.140e-01, Fail probs: 3.859e-01
# No. of non-dominant rules: 77, Survival rules: 46, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 20): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x19': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x68': ('>=', 1), 'x69': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 14, Unk. prob.: 1.000e-05
# Surv probs: 6.155e-01, Fail probs: 3.845e-01
# No. of non-dominant rules: 78, Survival rules: 47, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 200000.
# New rule (No. of conditions: 18): {'x1': ('>=', 1), 'x9': ('>=', 1), 'x20': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x61': ('>=', 1), 'x68': ('>=', 1), 'x70': ('>=', 1), 'x71': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 15, Unk. prob.: 1.000e-05
# Surv probs: 6.173e-01, Fail probs: 3.827e-01
# No. of non-dominant rules: 79, Survival rules: 48, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 21): {'x1': ('>=', 1), 'x9': ('>=', 1), 'x11': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x51': ('>=', 1), 'x52': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 16, Unk. prob.: 1.000e-05
# Surv probs: 6.139e-01, Fail probs: 3.861e-01
# No. of non-dominant rules: 80, Survival rules: 49, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 22): {'x2': ('>=', 1), 'x5': ('>=', 1), 'x6': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x38': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 17, Unk. prob.: 1.000e-05
# Surv probs: 6.172e-01, Fail probs: 3.828e-01
# No. of non-dominant rules: 81, Survival rules: 50, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 200000.
# New rule (No. of conditions: 17): {'x1': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x52': ('>=', 1), 'x53': ('>=', 1), 'x54': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 18, Unk. prob.: 5.000e-06
# Surv probs: 6.140e-01, Fail probs: 3.860e-01
# No. of non-dominant rules: 82, Survival rules: 51, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 200000.
# New rule (No. of conditions: 18): {'x2': ('>=', 1), 'x5': ('>=', 1), 'x16': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x38': ('>=', 1), 'x39': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x63': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 19, Unk. prob.: 5.000e-06
# Surv probs: 6.158e-01, Fail probs: 3.842e-01
# No. of non-dominant rules: 83, Survival rules: 52, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 17): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x20': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x68': ('>=', 1), 'x70': ('>=', 1), 'x71': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 20, Unk. prob.: 1.000e-05
# Surv probs: 6.160e-01, Fail probs: 3.840e-01
# No. of non-dominant rules: 84, Survival rules: 53, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 17): {'x2': ('>=', 1), 'x9': ('>=', 1), 'x16': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x63': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 21, Unk. prob.: 1.000e-05
# Surv probs: 6.166e-01, Fail probs: 3.834e-01
# No. of non-dominant rules: 85, Survival rules: 54, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 21): {'x2': ('>=', 1), 'x19': ('>=', 1), 'x21': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x68': ('>=', 1), 'x69': ('>=', 1), 'x70': ('>=', 1), 'x72': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 22, Unk. prob.: 1.000e-05
# Surv probs: 6.158e-01, Fail probs: 3.841e-01
# No. of non-dominant rules: 86, Survival rules: 55, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 300000.
# New rule (No. of conditions: 19): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x18': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x67': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 23, Unk. prob.: 3.333e-06
# Surv probs: 6.156e-01, Fail probs: 3.844e-01
# No. of non-dominant rules: 87, Survival rules: 56, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 18): {'x2': ('>=', 1), 'x10': ('>=', 1), 'x19': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x49': ('>=', 1), 'x50': ('>=', 1), 'x61': ('>=', 1), 'x68': ('>=', 1), 'x69': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 24, Unk. prob.: 1.000e-05
# Surv probs: 6.160e-01, Fail probs: 3.840e-01
# No. of non-dominant rules: 88, Survival rules: 57, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 17): {'x2': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x49': ('>=', 1), 'x50': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 25, Unk. prob.: 1.000e-05
# Surv probs: 6.180e-01, Fail probs: 3.820e-01
# No. of non-dominant rules: 89, Survival rules: 58, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 500000.
# New rule (No. of conditions: 16): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x9': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 26, Unk. prob.: 4.000e-06
# Surv probs: 6.153e-01, Fail probs: 3.847e-01
# No. of non-dominant rules: 90, Survival rules: 59, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 500000.
# New rule (No. of conditions: 20): {'x1': ('>=', 1), 'x9': ('>=', 1), 'x18': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x67': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 27, Unk. prob.: 4.000e-06
# Surv probs: 6.148e-01, Fail probs: 3.852e-01
# No. of non-dominant rules: 91, Survival rules: 60, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 400000.
# New rule (No. of conditions: 17): {'x1': ('>=', 1), 'x9': ('>=', 1), 'x11': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x51': ('>=', 1), 'x52': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 28, Unk. prob.: 2.500e-06
# Surv probs: 6.158e-01, Fail probs: 3.842e-01
# No. of non-dominant rules: 92, Survival rules: 61, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 200000.
# New rule (No. of conditions: 19): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x17': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x65': ('>=', 1), 'x66': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 29, Unk. prob.: 5.000e-06
# Surv probs: 6.149e-01, Fail probs: 3.851e-01
# No. of non-dominant rules: 93, Survival rules: 62, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 600000.
# New rule (No. of conditions: 18): {'x2': ('>=', 1), 'x4': ('>=', 1), 'x6': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x38': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 30, Unk. prob.: 1.667e-06
# Surv probs: 6.153e-01, Fail probs: 3.847e-01
# No. of non-dominant rules: 94, Survival rules: 63, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 300000.
# New rule (No. of conditions: 20): {'x2': ('>=', 1), 'x10': ('>=', 1), 'x18': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x49': ('>=', 1), 'x50': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x67': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 31, Unk. prob.: 3.333e-06
# Surv probs: 6.162e-01, Fail probs: 3.838e-01
# No. of non-dominant rules: 95, Survival rules: 64, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 21): {'x1': ('>=', 1), 'x5': ('>=', 1), 'x17': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x38': ('>=', 1), 'x39': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x65': ('>=', 1), 'x66': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 32, Unk. prob.: 1.000e-05
# Surv probs: 6.161e-01, Fail probs: 3.839e-01
# No. of non-dominant rules: 96, Survival rules: 65, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 16): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x11': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x52': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 33, Unk. prob.: 1.000e-05
# Surv probs: 6.160e-01, Fail probs: 3.840e-01
# No. of non-dominant rules: 97, Survival rules: 66, Failure rules: 31
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 500000.
# New rule (No. of conditions: 24): {'x1': ('>=', 1), 'x6': ('>=', 1), 'x8': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x38': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 1), 'x42': ('>=', 1), 'x44': ('>=', 1), 'x45': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 34, Unk. prob.: 2.000e-06
# Surv probs: 6.142e-01, Fail probs: 3.858e-01
# No. of non-dominant rules: 98, Survival rules: 67, Failure rules: 31
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 0.25. Total samples: 100000.
# New rule (No. of conditions: 7): {'x36': ('<=', 0), 'x48': ('<=', 0), 'x50': ('<=', 0), 'x51': ('<=', 0), 'x62': ('<=', 0), 'x69': ('<=', 0), 'x70': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [0.25, 0.5]
# ---
# Round: 35, Unk. prob.: 2.000e-05
# Surv probs: 6.174e-01, Fail probs: 3.826e-01
# No. of non-dominant rules: 99, Survival rules: 67, Failure rules: 32
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 800000.
# New rule (No. of conditions: 17): {'x1': ('>=', 1), 'x4': ('>=', 1), 'x9': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 36, Unk. prob.: 1.250e-06
# Surv probs: 6.162e-01, Fail probs: 3.838e-01
# No. of non-dominant rules: 100, Survival rules: 68, Failure rules: 32
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 500000.
# New rule (No. of conditions: 17): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x12': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x53': ('>=', 1), 'x54': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 37, Unk. prob.: 2.000e-06
# Surv probs: 6.160e-01, Fail probs: 3.840e-01
# No. of non-dominant rules: 101, Survival rules: 69, Failure rules: 32
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 0.25. Total samples: 500000.
# New rule (No. of conditions: 7): {'x9': ('<=', 0), 'x34': ('<=', 0), 'x38': ('<=', 0), 'x50': ('<=', 0), 'x51': ('<=', 0), 'x62': ('<=', 0), 'x68': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 38, Unk. prob.: 2.000e-06
# Surv probs: 6.163e-01, Fail probs: 3.837e-01
# No. of non-dominant rules: 102, Survival rules: 69, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 400000.
# New rule (No. of conditions: 17): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x10': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x49': ('>=', 1), 'x50': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 39, Unk. prob.: 2.500e-06
# Surv probs: 6.169e-01, Fail probs: 3.831e-01
# No. of non-dominant rules: 103, Survival rules: 70, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 900000.
# New rule (No. of conditions: 17): {'x2': ('>=', 1), 'x11': ('>=', 1), 'x12': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x52': ('>=', 1), 'x53': ('>=', 1), 'x54': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 40, Unk. prob.: 1.111e-06
# Surv probs: 6.155e-01, Fail probs: 3.845e-01
# No. of non-dominant rules: 104, Survival rules: 71, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 400000.
# New rule (No. of conditions: 21): {'x2': ('>=', 1), 'x17': ('>=', 1), 'x20': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x65': ('>=', 1), 'x66': ('>=', 1), 'x68': ('>=', 1), 'x70': ('>=', 1), 'x71': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 41, Unk. prob.: 2.500e-06
# Surv probs: 6.152e-01, Fail probs: 3.848e-01
# No. of non-dominant rules: 105, Survival rules: 72, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 300000.
# New rule (No. of conditions: 24): {'x1': ('>=', 1), 'x8': ('>=', 1), 'x18': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x38': ('>=', 1), 'x40': ('>=', 1), 'x42': ('>=', 1), 'x44': ('>=', 1), 'x45': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x67': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 42, Unk. prob.: 3.333e-06
# Surv probs: 6.156e-01, Fail probs: 3.844e-01
# No. of non-dominant rules: 106, Survival rules: 73, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 100000.
# New rule (No. of conditions: 18): {'x1': ('>=', 1), 'x5': ('>=', 1), 'x6': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x38': ('>=', 1), 'x39': ('>=', 1), 'x40': ('>=', 1), 'x41': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 43, Unk. prob.: 1.000e-05
# Surv probs: 6.163e-01, Fail probs: 3.837e-01
# No. of non-dominant rules: 107, Survival rules: 74, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 200000.
# New rule (No. of conditions: 18): {'x1': ('>=', 1), 'x20': ('>=', 1), 'x23': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x68': ('>=', 1), 'x70': ('>=', 1), 'x71': ('>=', 1), 'x73': ('>=', 1), 'x75': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 44, Unk. prob.: 5.000e-06
# Surv probs: 6.150e-01, Fail probs: 3.850e-01
# No. of non-dominant rules: 108, Survival rules: 75, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 400000.
# New rule (No. of conditions: 21): {'x2': ('>=', 1), 'x9': ('>=', 1), 'x10': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x49': ('>=', 1), 'x50': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 45, Unk. prob.: 2.500e-06
# Surv probs: 6.158e-01, Fail probs: 3.842e-01
# No. of non-dominant rules: 109, Survival rules: 76, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 600000.
# New rule (No. of conditions: 17): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x21': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x68': ('>=', 1), 'x70': ('>=', 1), 'x72': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 46, Unk. prob.: 1.667e-06
# Surv probs: 6.160e-01, Fail probs: 3.840e-01
# No. of non-dominant rules: 110, Survival rules: 77, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 200000.
# New rule (No. of conditions: 19): {'x2': ('>=', 1), 'x12': ('>=', 1), 'x14': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x53': ('>=', 1), 'x54': ('>=', 1), 'x55': ('>=', 1), 'x57': ('>=', 1), 'x58': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 47, Unk. prob.: 5.000e-06
# Surv probs: 6.166e-01, Fail probs: 3.834e-01
# No. of non-dominant rules: 111, Survival rules: 78, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 500000.
# New rule (No. of conditions: 16): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x16': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x63': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 48, Unk. prob.: 2.000e-06
# Surv probs: 6.148e-01, Fail probs: 3.852e-01
# No. of non-dominant rules: 112, Survival rules: 79, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 2200000.
# New rule (No. of conditions: 17): {'x1': ('>=', 1), 'x3': ('>=', 1), 'x5': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x38': ('>=', 1), 'x39': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 49, Unk. prob.: 4.545e-07
# Surv probs: 6.152e-01, Fail probs: 3.848e-01
# No. of non-dominant rules: 113, Survival rules: 80, Failure rules: 33
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 1300000.
# New rule (No. of conditions: 18): {'x1': ('>=', 1), 'x12': ('>=', 1), 'x19': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x53': ('>=', 1), 'x54': ('>=', 1), 'x61': ('>=', 1), 'x68': ('>=', 1), 'x69': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 50, Unk. prob.: 7.692e-07
# Surv probs: 6.150e-01, Fail probs: 3.850e-01
# No. of non-dominant rules: 114, Survival rules: 81, Failure rules: 33
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 0.25. Total samples: 100000.
# New rule (No. of conditions: 8): {'x3': ('<=', 0), 'x11': ('<=', 0), 'x36': ('<=', 0), 'x47': ('<=', 0), 'x53': ('<=', 0), 'x65': ('<=', 0), 'x66': ('<=', 0), 'x68': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 51, Unk. prob.: 1.000e-05
# Surv probs: 6.174e-01, Fail probs: 3.826e-01
# No. of non-dominant rules: 115, Survival rules: 81, Failure rules: 34
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 200000.
# New rule (No. of conditions: 18): {'x1': ('>=', 1), 'x4': ('>=', 1), 'x10': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x49': ('>=', 1), 'x50': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 52, Unk. prob.: 5.000e-06
# Surv probs: 6.156e-01, Fail probs: 3.844e-01
# No. of non-dominant rules: 116, Survival rules: 82, Failure rules: 34
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 400000.
# New rule (No. of conditions: 20): {'x1': ('>=', 1), 'x11': ('>=', 1), 'x16': ('>=', 1), 'x28': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x52': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x63': ('>=', 1), 'x64': ('>=', 1), 'x66': ('>=', 1), 'x82': ('>=', 1), 'x84': ('>=', 1), 'x85': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 53, Unk. prob.: 2.500e-06
# Surv probs: 6.158e-01, Fail probs: 3.842e-01
# No. of non-dominant rules: 117, Survival rules: 83, Failure rules: 34
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 800000.
# New rule (No. of conditions: 17): {'x1': ('>=', 1), 'x9': ('>=', 1), 'x16': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x47': ('>=', 1), 'x48': ('>=', 1), 'x61': ('>=', 1), 'x62': ('>=', 1), 'x63': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 54, Unk. prob.: 1.250e-06
# Surv probs: 6.155e-01, Fail probs: 3.845e-01
# No. of non-dominant rules: 118, Survival rules: 84, Failure rules: 34
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 600000.
# New rule (No. of conditions: 16): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x4': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x36': ('>=', 1), 'x37': ('>=', 1), 'x46': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 55, Unk. prob.: 1.667e-06
# Surv probs: 6.150e-01, Fail probs: 3.850e-01
# No. of non-dominant rules: 119, Survival rules: 85, Failure rules: 34
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 1400000.
# New rule (No. of conditions: 18): {'x2': ('>=', 1), 'x3': ('>=', 1), 'x13': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x32': ('>=', 1), 'x33': ('>=', 1), 'x34': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x53': ('>=', 1), 'x55': ('>=', 1), 'x56': ('>=', 1), 'x61': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 56, Unk. prob.: 7.143e-07
# Surv probs: 6.155e-01, Fail probs: 3.845e-01
# No. of non-dominant rules: 120, Survival rules: 86, Failure rules: 34
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 0.25. Total samples: 100000.
# New rule (No. of conditions: 6): {'x9': ('<=', 0), 'x36': ('<=', 0), 'x50': ('<=', 0), 'x51': ('<=', 0), 'x62': ('<=', 0), 'x68': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 57, Unk. prob.: 1.000e-05
# Surv probs: 6.158e-01, Fail probs: 3.841e-01
# No. of non-dominant rules: 121, Survival rules: 86, Failure rules: 35
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 0.5. Total samples: 600000.
# New rule (No. of conditions: 20): {'x1': ('>=', 1), 'x14': ('>=', 1), 'x19': ('>=', 1), 'x29': ('>=', 1), 'x30': ('>=', 1), 'x31': ('>=', 1), 'x33': ('>=', 1), 'x35': ('>=', 1), 'x46': ('>=', 1), 'x51': ('>=', 1), 'x53': ('>=', 1), 'x55': ('>=', 1), 'x57': ('>=', 1), 'x58': ('>=', 1), 'x61': ('>=', 1), 'x68': ('>=', 1), 'x69': ('>=', 1), 'x83': ('>=', 1), 'x86': ('>=', 1), 'x87': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 58, Unk. prob.: 1.667e-06
# Surv probs: 6.151e-01, Fail probs: 3.849e-01
# No. of non-dominant rules: 122, Survival rules: 87, Failure rules: 35
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 0.25. Total samples: 2700000.
# New rule (No. of conditions: 6): {'x3': ('<=', 0), 'x36': ('<=', 0), 'x49': ('<=', 0), 'x51': ('<=', 0), 'x62': ('<=', 0), 'x68': ('<=', 0), 'sys': ('<=', 0)}
# ---
# [Final results] Probs: 'surv':  6.156e-01, 'fail':  3.844e-01, 'unkn':  1.000e-06

# %%
TSUMPATH = Path("tsum_res_random")

sys_surv_st = 1  # system survival state

rules_mat_surv = torch.load(TSUMPATH / f"rules_geq_{sys_surv_st}.pt", map_location="cpu")
rules_mat_surv = rules_mat_surv.to(device)
rules_mat_fail = torch.load(TSUMPATH / f"rules_leq_{sys_surv_st-1}.pt", map_location="cpu")
rules_mat_fail = rules_mat_fail.to(device)

# %% [markdown]
# # Birnbaum's measure

# %%
bms_dict = {}

for x in probs_dict.keys():
    print(f"Calculating BM for {x}..")
    
    ps1_x1 = tsum.get_comp_cond_sys_prob(
        rules_mat_surv,
        rules_mat_fail,
        probs,
        comps_st_cond = {x: 1},
        row_names = row_names,
        s_fun = s_fun,
        sys_surv_st = sys_surv_st,
        n_sample = 10_000_000
    )

    ps1_x0 = tsum.get_comp_cond_sys_prob(
        rules_mat_surv,
        rules_mat_fail,
        probs,
        comps_st_cond = {x: 0},
        row_names = row_names,
        s_fun = s_fun,
        sys_surv_st = sys_surv_st,
        n_sample = 1_000_000
    )

    bm_x = max([0, ps1_x1['survival'] - ps1_x0['survival']])
    bms_dict[x] = bm_x

    print(f"BM({x}) = {bm_x:.3e}\n")

out_path = TSUMPATH / "bms_random.json"
with open(out_path, "w") as f:
    json.dump(bms_dict, f, indent=4)
# Out:
# Calculating BM for x1..
# BM(x1) = 4.936e-02
#
# Calculating BM for x2..
# BM(x2) = 8.422e-02
#
# Calculating BM for x3..
# BM(x3) = 3.860e-04
#
# Calculating BM for x4..
# BM(x4) = 0.000e+00
#
# Calculating BM for x5..
# BM(x5) = 2.667e-04
#
# Calculating BM for x6..
# BM(x6) = 3.086e-04
#
# Calculating BM for x7..
# BM(x7) = 7.830e-04
#
# Calculating BM for x8..
# BM(x8) = 0.000e+00
#
# Calculating BM for x9..
# BM(x9) = 0.000e+00
#
# Calculating BM for x10..
# BM(x10) = 0.000e+00
#
# Calculating BM for x11..
# BM(x11) = 9.640e-05
#
# Calculating BM for x12..
# BM(x12) = 0.000e+00
#
# Calculating BM for x13..
# BM(x13) = 0.000e+00
#
# Calculating BM for x14..
# BM(x14) = 0.000e+00
#
# Calculating BM for x15..
# BM(x15) = 9.679e-04
#
# Calculating BM for x16..
# BM(x16) = 9.253e-04
#
# Calculating BM for x17..
# BM(x17) = 3.476e-04
#
# Calculating BM for x18..
# BM(x18) = 6.540e-04
#
# Calculating BM for x19..
# BM(x19) = 2.421e-04
#
# Calculating BM for x20..
# BM(x20) = 5.248e-04
#
# Calculating BM for x21..
# BM(x21) = 0.000e+00
#
# Calculating BM for x22..
# BM(x22) = 3.480e-04
#
# Calculating BM for x23..
# BM(x23) = 0.000e+00
#
# Calculating BM for x24..
# BM(x24) = 1.741e-03
#
# Calculating BM for x25..
# BM(x25) = 0.000e+00
#
# Calculating BM for x26..
# BM(x26) = 6.235e-04
#
# Calculating BM for x27..
# BM(x27) = 9.580e-05
#
# Calculating BM for x28..
# BM(x28) = 7.335e-02
#
# Calculating BM for x29..
# BM(x29) = 2.051e-01
#
# Calculating BM for x30..
# BM(x30) = 6.584e-01
#
# Calculating BM for x31..
# BM(x31) = 5.029e-02
#
# Calculating BM for x32..
# BM(x32) = 8.913e-02
#
# Calculating BM for x33..
# BM(x33) = 6.538e-01
#
# Calculating BM for x34..
# BM(x34) = 0.000e+00
#
# Calculating BM for x35..
# BM(x35) = 6.439e-01
#
# Calculating BM for x36..
# BM(x36) = 6.082e-04
#
# Calculating BM for x37..
# BM(x37) = 9.695e-04
#
# Calculating BM for x38..
# BM(x38) = 0.000e+00
#
# Calculating BM for x39..
# BM(x39) = 0.000e+00
#
# Calculating BM for x40..
# BM(x40) = 0.000e+00
#
# Calculating BM for x41..
# BM(x41) = 7.971e-04
#
# Calculating BM for x42..
# BM(x42) = 0.000e+00
#
# Calculating BM for x43..
# BM(x43) = 0.000e+00
#
# Calculating BM for x44..
# BM(x44) = 3.923e-04
#
# Calculating BM for x45..
# BM(x45) = 5.130e-05
#
# Calculating BM for x46..
# BM(x46) = 6.351e-01
#
# Calculating BM for x47..
# BM(x47) = 0.000e+00
#
# Calculating BM for x48..
# BM(x48) = 0.000e+00
#
# Calculating BM for x49..
# BM(x49) = 4.486e-04
#
# Calculating BM for x50..
# BM(x50) = 7.505e-04
#
# Calculating BM for x51..
# BM(x51) = 3.480e-05
#
# Calculating BM for x52..
# BM(x52) = 2.837e-04
#
# Calculating BM for x53..
# BM(x53) = 4.297e-04
#
# Calculating BM for x54..
# BM(x54) = 0.000e+00
#
# Calculating BM for x55..
# BM(x55) = 1.029e-04
#
# Calculating BM for x56..
# BM(x56) = 2.031e-04
#
# Calculating BM for x57..
# BM(x57) = 0.000e+00
#
# Calculating BM for x58..
# BM(x58) = 0.000e+00
#
# Calculating BM for x59..
# BM(x59) = 3.362e-04
#
# Calculating BM for x60..
# BM(x60) = 0.000e+00
#
# Calculating BM for x61..
# BM(x61) = 6.832e-01
#
# Calculating BM for x62..
# BM(x62) = 7.815e-02
#
# Calculating BM for x63..
# BM(x63) = 2.800e-04
#
# Calculating BM for x64..
# BM(x64) = 7.785e-02
#
# Calculating BM for x65..
# BM(x65) = 6.081e-04
#
# Calculating BM for x66..
# BM(x66) = 7.928e-02
#
# Calculating BM for x67..
# BM(x67) = 2.360e-05
#
# Calculating BM for x68..
# BM(x68) = 1.097e-04
#
# Calculating BM for x69..
# BM(x69) = 8.764e-04
#
# Calculating BM for x70..
# BM(x70) = 5.900e-05
#
# Calculating BM for x71..
# BM(x71) = 0.000e+00
#
# Calculating BM for x72..
# BM(x72) = 0.000e+00
#
# Calculating BM for x73..
# BM(x73) = 3.392e-04
#
# Calculating BM for x74..
# BM(x74) = 0.000e+00
#
# Calculating BM for x75..
# BM(x75) = 0.000e+00
#
# Calculating BM for x76..
# BM(x76) = 0.000e+00
#
# Calculating BM for x77..
# BM(x77) = 0.000e+00
#
# Calculating BM for x78..
# BM(x78) = 2.194e-04
#
# Calculating BM for x79..
# BM(x79) = 3.359e-04
#
# Calculating BM for x80..
# BM(x80) = 3.805e-04
#
# Calculating BM for x81..
# BM(x81) = 0.000e+00
#
# Calculating BM for x82..
# BM(x82) = 7.509e-02
#
# Calculating BM for x83..
# BM(x83) = 1.993e-01
#
# Calculating BM for x84..
# BM(x84) = 8.001e-02
#
# Calculating BM for x85..
# BM(x85) = 7.545e-02
#
# Calculating BM for x86..
# BM(x86) = 1.929e-01
#
# Calculating BM for x87..
# BM(x87) = 6.841e-01
