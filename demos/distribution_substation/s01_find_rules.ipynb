# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent.parent))  # add repo root
from tsum import tsum
import torch
import json, os

from pathlib import Path 

from distribution_substation_liang2022.v1.scripts import utils_sub # available at github.com/jieunbyun/network-datasets 

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
DATASET = Path("data") 

nodes = json.loads((DATASET / "nodes.json").read_text(encoding="utf-8"))
edges = json.loads((DATASET / "edges.json").read_text(encoding="utf-8"))

row_names = list(edges.keys()) + ['sys']

n_comp = len(edges)
n_var = n_comp + 1  # components + system
n_state = 2 # binary states: working (1) or failed (0)

# %%
def sfun_subs(comps_st, thres=360):
    node_groups = utils_sub.process_nodes(nodes)
    capacity = utils_sub.sys_fun(comps_st, edges, nodes, node_groups, return_details=False)

    if capacity >= thres:
        return capacity, 's', None
    else:
        return capacity, 'f', None

# %%
import importlib
importlib.reload(utils_sub)
# Out:
# <module 'distribution_substation_liang2022.v1.scripts.utils_sub' from 'C:\\Users\\jb622s\\git\\network-datasets\\distribution_substation_liang2022\\v1\\scripts\\utils_sub.py'>

# %% [markdown]
# # Find rules over thresholds

# %%
pga_str_list = ['0_1g', '0_2g', '0_3g', '0_4g', '0_5g']
for pga_str in pga_str_list:
    print(f"--- {pga_str} ---")
    with open(rf"data\probs_{pga_str}.json", "r") as f: 
        probs_dict = json.load(f)
    
    probs = [[probs_dict[n]['0']['p'], probs_dict[n]['1']['p']] for n in row_names[:-1]]
    probs = torch.tensor(probs, dtype=torch.float32, device=device)

    # Threshold values to start with
    if os.path.exists(r"tsum_res/thres_list.json"):
        with open(r"tsum_res/thres_list.json", "r") as f:
            thres_list = json.load(f)
            thres_isdone = [False]*len(thres_list)

            if 0 in thres_list: 
                idx_0 = thres_list.index(0)
                thres_isdone[idx_0] = True # 0 threshold doesn't need to be computed
    else:
        thres_list = [360]
        thres_isdone = [False]
        with open(r"tsum_res/thres_list.json", "w") as f:
            json.dump(thres_list, f, indent=4)

    while not all(thres_isdone):

        # get the next highest threshold to compute
        i, t = next((i, t) for i, (t, done) in enumerate(zip(thres_list, thres_isdone)) if not done)
        thres_isdone[i] = True
        print(f"Threshold: {t}..")

        # initialisation
        sfun = lambda comps_st: sfun_subs(comps_st, thres=t)

        # Load previous rules if available from previous runs with other pga values
        if os.path.exists(Path("tsum_res") / f"rules_surv_{t}.json"):
            rules_surv = json.loads((Path("tsum_res") / f"rules_surv_{t}.json").read_text(encoding="utf-8"))
            rules_fail = json.loads((Path("tsum_res") / f"rules_fail_{t}.json").read_text(encoding="utf-8"))
            rules_mat_surv = torch.load(Path("tsum_res") / f"rules_surv_{t}.pt", map_location="cpu")
            rules_mat_surv = rules_mat_surv.to(device)
            rules_mat_fail = torch.load(Path("tsum_res") / f"rules_fail_{t}.pt", map_location="cpu")
            rules_mat_fail = rules_mat_fail.to(device)
        else:
            rules_surv = []
            rules_fail = []
            rules_mat_surv = None
            rules_mat_fail = None
            
        # find rules
        result = tsum.run_rule_extraction(
            sfun = sfun,
            probs = probs,
            row_names = row_names,
            n_state=n_state,
            rules_surv = rules_surv,
            rules_fail = rules_fail,
            rules_mat_surv = rules_mat_surv,
            rules_mat_fail = rules_mat_fail,
            output_dir = "tsum_res",
            surv_json_name = f"rules_surv_{t}.json",
            fail_json_name = f"rules_fail_{t}.json",
            surv_pt_name = f"rules_surv_{t}.pt",
            fail_pt_name = f"rules_fail_{t}.pt",
            metrics_path = f"metrics_{t}.jsonl",
            unk_prob_thres = 1e-6,
        )

        for s in result['sys_vals']:
            s=int(s)
            if s not in thres_list:
                thres_list.append(s)
                if s == 0:
                    thres_isdone.append(True) # no need to work on threshold 0
                else:
                    thres_isdone.append(False)
                # Sort the two lists by descending order of thres_list
                pairs = list(zip(thres_list, thres_isdone))
                pairs.sort(key=lambda x: x[0], reverse=True)
                thres_list, thres_isdone = map(list, zip(*pairs))
        print(f"Updated thres_list: {thres_list}")
        with open(r"tsum_res/thres_list.json", "w") as f:
            json.dump(thres_list, f, indent=4)
# Out:
# --- 0_1g ---
# Threshold: 360..
# ---
# Round: 1, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 20, Survival rules: 6, Failure rules: 14
# C:\Users\jb622s\AppData\Local\Temp\ipykernel_40684\1737172208.py:39: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   rules_mat_surv = torch.load(Path("tsum_res") / f"rules_surv_{t}.pt", map_location="cpu")
# C:\Users\jb622s\AppData\Local\Temp\ipykernel_40684\1737172208.py:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   rules_mat_fail = torch.load(Path("tsum_res") / f"rules_fail_{t}.pt", map_location="cpu")
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 348.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_17': ('<=', 0), 'M_DS110_29': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [348.0]
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_18': ('<=', 0), 'M_DS110_30': ('<=', 0), 'sys': ('<=', 0)}
# Unique system values: [0.0, 348.0]
# ---
# Round: 2, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 22, Survival rules: 6, Failure rules: 16
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Updated sys_vals: [0.0, 348.0, 360.0]
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_Bus110_2': ('<=', 0), 'M_DS110_13': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 3, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 24, Survival rules: 7, Failure rules: 17
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 348.0. Total samples: 1024.
# New rule (No. of conditions: 1): {'M_Line110_6': ('<=', 0), 'sys': ('<=', 0)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_5': ('<=', 0), 'M_DS220_6': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 4, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 26, Survival rules: 7, Failure rules: 19
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_14': ('<=', 0), 'M_DS110_26': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 5, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 28, Survival rules: 8, Failure rules: 20
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_7': ('<=', 0), 'M_DS220_8': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 6, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 30, Survival rules: 9, Failure rules: 21
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_1': ('<=', 0), 'M_Bus220_2': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 7, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 32, Survival rules: 10, Failure rules: 22
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 1): {'M_Line110_4': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 8, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 34, Survival rules: 11, Failure rules: 23
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_8': ('<=', 0), 'M_DS110_20': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 9, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 36, Survival rules: 12, Failure rules: 24
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 352.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_13': ('<=', 0), 'M_DS110_25': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [0.0, 348.0, 352.0, 360.0]
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_Bus110_2': ('<=', 0), 'M_DS110_10': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 10, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 38, Survival rules: 12, Failure rules: 26
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 5): {'M_TF_1': ('<=', 0), 'M_DS110_4': ('<=', 0), 'M_DS110_6': ('<=', 0), 'M_BC110_2': ('<=', 0), 'M_DS110_18': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 11, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 40, Survival rules: 13, Failure rules: 27
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 180.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_TF_2': ('<=', 0), 'M_TF_4': ('<=', 0), 'M_DS110_2': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [0.0, 180.0, 348.0, 352.0, 360.0]
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_3': ('<=', 0), 'M_DS220_4': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 12, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 42, Survival rules: 13, Failure rules: 29
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 348.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_11': ('<=', 0), 'M_DS110_23': ('<=', 0), 'sys': ('<=', 0)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_9': ('<=', 0), 'M_DS110_21': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 13, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 44, Survival rules: 13, Failure rules: 31
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 350.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_16': ('<=', 0), 'M_DS110_28': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [0.0, 180.0, 348.0, 350.0, 352.0, 360.0]
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_Bus110_1': ('<=', 0), 'M_DS110_25': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 14, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 46, Survival rules: 13, Failure rules: 33
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 348.0. Total samples: 1024.
# New rule (No. of conditions: 1): {'M_Line110_12': ('<=', 0), 'sys': ('<=', 0)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 1): {'M_Line220_4': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 15, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 48, Survival rules: 13, Failure rules: 35
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_12': ('<=', 0), 'M_DS110_24': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 16, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 50, Survival rules: 14, Failure rules: 36
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_9': ('<=', 0), 'M_DS220_10': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 17, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 52, Survival rules: 15, Failure rules: 37
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 180.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_TF_2': ('<=', 0), 'M_TF_3': ('<=', 0), 'sys': ('<=', 0)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_10': ('<=', 0), 'M_DS110_22': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 18, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 54, Survival rules: 15, Failure rules: 39
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 348.0. Total samples: 1024.
# New rule (No. of conditions: 1): {'M_Line110_11': ('<=', 0), 'sys': ('<=', 0)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS110_7': ('<=', 0), 'M_DS110_19': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 19, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 56, Survival rules: 15, Failure rules: 41
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_DS220_15': ('<=', 0), 'M_DS220_18': ('<=', 0), 'M_TF_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 20, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 58, Survival rules: 16, Failure rules: 42
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_2': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_Bus110_1': ('<=', 0), 'M_DS110_27': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 21, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 60, Survival rules: 17, Failure rules: 43
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 4): {'M_DS220_15': ('<=', 0), 'M_DS220_18': ('<=', 0), 'M_TF_4': ('<=', 0), 'M_DS110_2': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 22, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 62, Survival rules: 18, Failure rules: 44
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 180.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_TF_1': ('<=', 0), 'M_TF_2': ('<=', 0), 'sys': ('<=', 0)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_7': ('<=', 0), 'M_Bus220_2': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 23, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 64, Survival rules: 18, Failure rules: 46
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 48): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_11': ('<=', 0), 'M_Bus220_2': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 24, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 66, Survival rules: 19, Failure rules: 47
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_2': ('<=', 0), 'M_Bus220_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 25, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 68, Survival rules: 20, Failure rules: 48
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 5): {'M_DS220_8': ('<=', 0), 'M_BC220_2': ('<=', 0), 'M_DS220_13': ('<=', 0), 'M_DS220_14': ('<=', 0), 'M_DS220_15': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 26, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 70, Survival rules: 21, Failure rules: 49
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 5): {'M_TF_1': ('<=', 0), 'M_DS110_3': ('<=', 0), 'M_DS110_5': ('<=', 0), 'M_BC110_1': ('<=', 0), 'M_DS110_27': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 27, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 72, Survival rules: 22, Failure rules: 50
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_DS220_14': ('<=', 0), 'M_DS220_17': ('<=', 0), 'M_TF_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 28, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 74, Survival rules: 23, Failure rules: 51
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 48): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_6': ('<=', 0), 'M_Bus220_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 29, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 76, Survival rules: 24, Failure rules: 52
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_TF_3': ('<=', 0), 'M_DS110_3': ('<=', 0), 'M_DS110_4': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 30, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 78, Survival rules: 25, Failure rules: 53
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_Bus110_2': ('<=', 0), 'M_DS110_17': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 31, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 80, Survival rules: 26, Failure rules: 54
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_Bus110_1': ('<=', 0), 'M_DS110_28': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 32, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 82, Survival rules: 27, Failure rules: 55
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 48): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_Bus110_2': ('<=', 0), 'M_DS110_14': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 33, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 84, Survival rules: 28, Failure rules: 56
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# ...
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 4): {'M_DS220_14': ('<=', 0), 'M_DS220_17': ('<=', 0), 'M_TF_4': ('<=', 0), 'M_DS110_2': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 56, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 110, Survival rules: 45, Failure rules: 65
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 350.0. Total samples: 1024.
# New rule (No. of conditions: 43): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 4): {'M_DS220_13': ('<=', 0), 'M_DS220_15': ('<=', 0), 'M_DS220_16': ('<=', 0), 'M_DS220_18': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 57, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 112, Survival rules: 46, Failure rules: 66
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 352.0. Total samples: 1024.
# New rule (No. of conditions: 43): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 5): {'M_DS220_10': ('<=', 0), 'M_BC220_2': ('<=', 0), 'M_DS220_13': ('<=', 0), 'M_DS220_14': ('<=', 0), 'M_DS220_15': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 58, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 114, Survival rules: 47, Failure rules: 67
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 1024.
# New rule (No. of conditions: 44): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_DS220_14': ('<=', 0), 'M_DS220_17': ('<=', 0), 'M_TF_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 59, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 116, Survival rules: 48, Failure rules: 68
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 350.0. Total samples: 1024.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_DS220_7': ('<=', 0), 'M_DS220_8': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 60, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 118, Survival rules: 49, Failure rules: 69
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 350.0. Total samples: 1024.
# New rule (No. of conditions: 43): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_DS110_15': ('<=', 0), 'M_DS110_27': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 61, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 120, Survival rules: 50, Failure rules: 70
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 350.0. Total samples: 1024.
# New rule (No. of conditions: 44): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 180.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_DS110_16': ('<=', 0), 'M_DS110_28': ('<=', 0), 'M_Line110_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 62, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 122, Survival rules: 51, Failure rules: 71
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 350.0. Total samples: 1024.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_1': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 180.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_TF_2': ('<=', 0), 'M_DS110_6': ('<=', 0), 'M_Bus110_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 63, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 124, Survival rules: 52, Failure rules: 72
# Survival sample found from survival rules 👍
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 352.0. Total samples: 1024.
# New rule (No. of conditions: 44): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_DS110_13': ('<=', 0), 'M_DS110_25': ('<=', 0), 'M_Line110_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 64, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 126, Survival rules: 53, Failure rules: 73
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 342.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_Line110_8': ('<=', 0), 'M_Line110_9': ('<=', 0), 'sys': ('<=', 0)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 0.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_DS220_14': ('<=', 0), 'M_DS220_17': ('<=', 0), 'M_TF_3': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 65, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 128, Survival rules: 53, Failure rules: 75
# Failure sample found from survival rules 👍👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 340.0. Total samples: 1024.
# New rule (No. of conditions: 2): {'M_Line110_4': ('<=', 0), 'M_Line110_9': ('<=', 0), 'sys': ('<=', 0)}
# Failure sample found from failure rules 👍
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 108.0. Total samples: 1024.
# New rule (No. of conditions: 3): {'M_DS110_9': ('<=', 0), 'M_DS110_21': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 0)}
# Unique system values: [0.0, 108.0, 180.0, 312.0, 340.0, 342.0, 344.0, 348.0, 350.0, 352.0, 360.0]
# ---
# Round: 66, Unk. prob.: 5.501e-03
# No. of non-dominant rules: 130, Survival rules: 53, Failure rules: 77
