# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent.parent))  # add repo root
from tsum import tsum
import torch
import json, os

from pathlib import Path 

from distribution_substation_liang2022.v1.scripts import utils_sub # available at github.com/jieunbyun/network-datasets 

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
DATASET = Path("data") 

nodes = json.loads((DATASET / "nodes.json").read_text(encoding="utf-8"))
edges = json.loads((DATASET / "edges.json").read_text(encoding="utf-8"))

row_names = list(edges.keys())

n_comp = len(edges)
n_state = 2 # binary states: working (1) or failed (0)

# %%
sys_surv_st = 2
thres_list = [180, 300]  # capacity thresholds: if capacity < thres[i], system state = i: maximum capacity is 360

# %%
def sfun_subs(comps_st):
    node_groups = utils_sub.process_nodes(nodes)
    capacity = utils_sub.sys_fun(comps_st, edges, nodes, node_groups, return_details=False)

    sys_st = next((i for i, t in enumerate(thres_list) if t > capacity), len(thres_list))

    return capacity, sys_st, None

# %% [markdown]
# # Find rules over thresholds

# %%
pga_str = '0_2g'

with open(rf"data\probs_{pga_str}.json", "r") as f: 
    probs_dict = json.load(f)
probs = [[probs_dict[n]['0']['p'], probs_dict[n]['1']['p']] for n in row_names]
probs = torch.tensor(probs, dtype=torch.float32, device=device)

result = tsum.run_rule_extraction_by_mcs(
    sfun = sfun_subs,
    probs = probs,
    row_names = row_names,
    n_state = n_state,
    output_dir = "tsum_res",
    unk_prob_thres = 1e-3,
    sys_surv_st = sys_surv_st
)
# Out:
# ---
# Round: 1, Unk. prob.: 1.000e+00
# Surv probs: 0.000e+00, Fail probs: 0.000e+00
# No. of non-dominant rules: 0, Survival rules: 0, Failure rules: 0
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_TF_2': ('<=', 0), 'M_TF_3': ('<=', 0), 'sys': ('<=', 1)}
# Updated sys_vals: [180.0]
# ---
# Round: 2, Unk. prob.: 1.000e+00
# Surv probs: 0.000e+00, Fail probs: 0.000e+00
# No. of non-dominant rules: 1, Survival rules: 0, Failure rules: 1
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 216.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line220_6': ('<=', 0), 'M_DS220_9': ('<=', 0), 'M_DS220_10': ('<=', 0), 'sys': ('<=', 1)}
# Updated sys_vals: [180.0, 216.0]
# ---
# Round: 3, Unk. prob.: 4.375e-01
# Surv probs: 0.000e+00, Fail probs: 5.625e-01
# No. of non-dominant rules: 2, Survival rules: 0, Failure rules: 2
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_Line110_5': ('<=', 0), 'M_Line110_6': ('<=', 0), 'sys': ('<=', 1)}
# Updated sys_vals: [180.0, 216.0, 288.0]
# ---
# Round: 4, Unk. prob.: 4.325e-01
# Surv probs: 0.000e+00, Fail probs: 5.675e-01
# No. of non-dominant rules: 3, Survival rules: 0, Failure rules: 3
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_3': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_7': ('<=', 0), 'sys': ('<=', 1)}
# Updated sys_vals: [180.0, 216.0, 288.0, 292.0]
# ---
# Round: 5, Unk. prob.: 3.049e-01
# Surv probs: 0.000e+00, Fail probs: 6.951e-01
# No. of non-dominant rules: 4, Survival rules: 0, Failure rules: 4
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_5': ('<=', 0), 'sys': ('<=', 1)}
# Updated sys_vals: [180.0, 216.0, 288.0, 290.0, 292.0]
# ---
# Round: 6, Unk. prob.: 2.506e-01
# Surv probs: 0.000e+00, Fail probs: 7.494e-01
# No. of non-dominant rules: 5, Survival rules: 0, Failure rules: 5
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_Line110_11': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 7, Unk. prob.: 2.387e-01
# Surv probs: 0.000e+00, Fail probs: 7.613e-01
# No. of non-dominant rules: 6, Survival rules: 0, Failure rules: 6
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_TF_1': ('<=', 0), 'M_TF_3': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 8, Unk. prob.: 1.672e-01
# Surv probs: 0.000e+00, Fail probs: 8.328e-01
# No. of non-dominant rules: 7, Survival rules: 0, Failure rules: 7
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_DS110_11': ('<=', 0), 'M_DS110_23': ('<=', 0), 'M_Line110_6': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 9, Unk. prob.: 1.137e-01
# Surv probs: 0.000e+00, Fail probs: 8.863e-01
# No. of non-dominant rules: 8, Survival rules: 0, Failure rules: 8
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_TF_1': ('<=', 0), 'M_DS110_3': ('<=', 0), 'M_Bus110_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 10, Unk. prob.: 1.104e-01
# Surv probs: 0.000e+00, Fail probs: 8.896e-01
# No. of non-dominant rules: 9, Survival rules: 0, Failure rules: 9
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_TF_1': ('<=', 0), 'M_DS110_5': ('<=', 0), 'M_DS110_6': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 11, Unk. prob.: 1.045e-01
# Surv probs: 0.000e+00, Fail probs: 8.955e-01
# No. of non-dominant rules: 10, Survival rules: 0, Failure rules: 10
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_TF_1': ('<=', 0), 'M_TF_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 12, Unk. prob.: 1.031e-01
# Surv probs: 0.000e+00, Fail probs: 8.969e-01
# No. of non-dominant rules: 11, Survival rules: 0, Failure rules: 11
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Bus110_1': ('<=', 0), 'M_DS110_19': ('<=', 0), 'M_Line110_9': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 13, Unk. prob.: 5.582e-02
# Surv probs: 0.000e+00, Fail probs: 9.442e-01
# No. of non-dominant rules: 12, Survival rules: 0, Failure rules: 12
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_DS110_8': ('<=', 0), 'M_DS110_20': ('<=', 0), 'M_Line110_1': ('<=', 0), 'M_Line110_8': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 14, Unk. prob.: 5.431e-02
# Surv probs: 0.000e+00, Fail probs: 9.457e-01
# No. of non-dominant rules: 13, Survival rules: 0, Failure rules: 13
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_6': ('<=', 0), 'M_Line110_9': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 15, Unk. prob.: 5.447e-02
# Surv probs: 0.000e+00, Fail probs: 9.455e-01
# No. of non-dominant rules: 14, Survival rules: 0, Failure rules: 14
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Bus110_2': ('<=', 0), 'M_DS110_15': ('<=', 0), 'M_DS110_16': ('<=', 0), 'M_Line110_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 16, Unk. prob.: 5.043e-02
# Surv probs: 0.000e+00, Fail probs: 9.496e-01
# No. of non-dominant rules: 15, Survival rules: 0, Failure rules: 15
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Bus220_1': ('<=', 0), 'M_DS220_17': ('<=', 0), 'M_TF_3': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 17, Unk. prob.: 4.819e-02
# Surv probs: 0.000e+00, Fail probs: 9.518e-01
# No. of non-dominant rules: 16, Survival rules: 0, Failure rules: 16
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_Bus110_2': ('<=', 0), 'M_DS110_13': ('<=', 0), 'M_DS110_18': ('<=', 0), 'M_Line110_8': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 18, Unk. prob.: 4.905e-02
# Surv probs: 0.000e+00, Fail probs: 9.509e-01
# No. of non-dominant rules: 17, Survival rules: 0, Failure rules: 17
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 6): {'M_TF_2': ('<=', 0), 'M_TF_4': ('<=', 0), 'M_DS110_5': ('<=', 0), 'M_BC110_1': ('<=', 0), 'M_DS110_29': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 19, Unk. prob.: 4.835e-02
# Surv probs: 0.000e+00, Fail probs: 9.516e-01
# No. of non-dominant rules: 18, Survival rules: 0, Failure rules: 18
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 240.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_Line220_3': ('<=', 0), 'M_Line220_4': ('<=', 0), 'sys': ('<=', 1)}
# Updated sys_vals: [180.0, 216.0, 240.0, 288.0, 290.0, 292.0]
# ---
# Round: 20, Unk. prob.: 4.797e-02
# Surv probs: 0.000e+00, Fail probs: 9.520e-01
# No. of non-dominant rules: 19, Survival rules: 0, Failure rules: 19
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 264.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_Line220_1': ('<=', 0), 'M_Line220_2': ('<=', 0), 'sys': ('<=', 1)}
# Updated sys_vals: [180.0, 216.0, 240.0, 264.0, 288.0, 290.0, 292.0]
# ---
# Round: 21, Unk. prob.: 3.941e-02
# Surv probs: 0.000e+00, Fail probs: 9.606e-01
# No. of non-dominant rules: 20, Survival rules: 0, Failure rules: 20
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 294.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 1)}
# Updated sys_vals: [180.0, 216.0, 240.0, 264.0, 288.0, 290.0, 292.0, 294.0]
# ---
# Round: 22, Unk. prob.: 3.190e-02
# Surv probs: 0.000e+00, Fail probs: 9.681e-01
# No. of non-dominant rules: 21, Survival rules: 0, Failure rules: 21
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_Bus110_1': ('<=', 0), 'M_DS110_21': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'M_Line110_9': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 23, Unk. prob.: 3.015e-02
# Surv probs: 0.000e+00, Fail probs: 9.698e-01
# No. of non-dominant rules: 22, Survival rules: 0, Failure rules: 22
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_7': ('<=', 0), 'M_Line110_9': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 24, Unk. prob.: 3.055e-02
# Surv probs: 0.000e+00, Fail probs: 9.695e-01
# No. of non-dominant rules: 23, Survival rules: 0, Failure rules: 23
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 264.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_DS220_2': ('<=', 0), 'M_DS220_4': ('<=', 0), 'M_Bus220_1': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 25, Unk. prob.: 2.791e-02
# Surv probs: 0.000e+00, Fail probs: 9.721e-01
# No. of non-dominant rules: 24, Survival rules: 0, Failure rules: 24
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_2': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_4': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 26, Unk. prob.: 2.686e-02
# Surv probs: 0.000e+00, Fail probs: 9.731e-01
# No. of non-dominant rules: 25, Survival rules: 0, Failure rules: 25
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_DS110_12': ('<=', 0), 'M_DS110_24': ('<=', 0), 'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_9': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 27, Unk. prob.: 2.464e-02
# Surv probs: 0.000e+00, Fail probs: 9.754e-01
# No. of non-dominant rules: 26, Survival rules: 0, Failure rules: 26
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_9': ('<=', 0), 'M_Line110_11': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 28, Unk. prob.: 2.491e-02
# Surv probs: 0.000e+00, Fail probs: 9.751e-01
# No. of non-dominant rules: 27, Survival rules: 0, Failure rules: 27
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_6': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 29, Unk. prob.: 2.434e-02
# Surv probs: 0.000e+00, Fail probs: 9.757e-01
# No. of non-dominant rules: 28, Survival rules: 0, Failure rules: 28
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_6': ('<=', 0), 'M_Line110_9': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 30, Unk. prob.: 2.403e-02
# Surv probs: 0.000e+00, Fail probs: 9.760e-01
# No. of non-dominant rules: 29, Survival rules: 0, Failure rules: 29
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 216.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_Line220_5': ('<=', 0), 'M_Line220_6': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 31, Unk. prob.: 2.235e-02
# Surv probs: 0.000e+00, Fail probs: 9.777e-01
# No. of non-dominant rules: 30, Survival rules: 0, Failure rules: 30
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_TF_2': ('<=', 0), 'M_DS110_5': ('<=', 0), 'M_DS110_6': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 32, Unk. prob.: 1.890e-02
# Surv probs: 0.000e+00, Fail probs: 9.811e-01
# No. of non-dominant rules: 31, Survival rules: 0, Failure rules: 31
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_DS110_8': ('<=', 0), 'M_DS110_20': ('<=', 0), 'M_Line110_1': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_5': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 33, Unk. prob.: 1.825e-02
# Surv probs: 0.000e+00, Fail probs: 9.818e-01
# No. of non-dominant rules: 32, Survival rules: 0, Failure rules: 32
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Bus220_1': ('<=', 0), 'M_DS220_18': ('<=', 0), 'M_TF_1': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 34, Unk. prob.: 1.765e-02
# Surv probs: 0.000e+00, Fail probs: 9.823e-01
# No. of non-dominant rules: 33, Survival rules: 0, Failure rules: 33
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_TF_3': ('<=', 0), 'M_TF_4': ('<=', 0), 'M_DS110_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 35, Unk. prob.: 1.795e-02
# Surv probs: 0.000e+00, Fail probs: 9.820e-01
# No. of non-dominant rules: 34, Survival rules: 0, Failure rules: 34
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 8): {'M_TF_2': ('<=', 0), 'M_TF_4': ('<=', 0), 'M_DS110_5': ('<=', 0), 'M_BC110_1': ('<=', 0), 'M_DS110_28': ('<=', 0), 'M_DS110_30': ('<=', 0), 'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 36, Unk. prob.: 1.696e-02
# Surv probs: 0.000e+00, Fail probs: 9.830e-01
# No. of non-dominant rules: 35, Survival rules: 0, Failure rules: 35
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 28): {'M_Line220_1': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 2)}
# Updated sys_vals: [180.0, 216.0, 240.0, 264.0, 288.0, 290.0, 292.0, 294.0, 300]
# ---
# Round: 37, Unk. prob.: 1.752e-02
# Surv probs: 0.000e+00, Fail probs: 9.825e-01
# No. of non-dominant rules: 36, Survival rules: 1, Failure rules: 35
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_4': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'M_Line110_11': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 38, Unk. prob.: 1.677e-02
# Surv probs: 0.000e+00, Fail probs: 9.832e-01
# No. of non-dominant rules: 37, Survival rules: 1, Failure rules: 36
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 27): {'M_Line220_1': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 39, Unk. prob.: 1.669e-02
# Surv probs: 0.000e+00, Fail probs: 9.833e-01
# No. of non-dominant rules: 38, Survival rules: 2, Failure rules: 36
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 294.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_2': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 40, Unk. prob.: 1.669e-02
# Surv probs: 0.000e+00, Fail probs: 9.833e-01
# No. of non-dominant rules: 39, Survival rules: 2, Failure rules: 37
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_3': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_5': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 41, Unk. prob.: 1.627e-02
# Surv probs: 0.000e+00, Fail probs: 9.837e-01
# No. of non-dominant rules: 40, Survival rules: 2, Failure rules: 38
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Bus110_2': ('<=', 0), 'M_DS110_15': ('<=', 0), 'M_DS110_16': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 42, Unk. prob.: 1.602e-02
# Surv probs: 0.000e+00, Fail probs: 9.840e-01
# No. of non-dominant rules: 41, Survival rules: 2, Failure rules: 39
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Bus110_2': ('<=', 0), 'M_DS110_15': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_4': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 43, Unk. prob.: 1.603e-02
# Surv probs: 1.000e-05, Fail probs: 9.840e-01
# No. of non-dominant rules: 42, Survival rules: 2, Failure rules: 40
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 28): {'M_Line220_2': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_11': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 44, Unk. prob.: 1.521e-02
# Surv probs: 0.000e+00, Fail probs: 9.848e-01
# No. of non-dominant rules: 43, Survival rules: 3, Failure rules: 40
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 264.0. Total samples: 100000.
# New rule (No. of conditions: 6): {'M_Line220_2': ('<=', 0), 'M_DS220_2': ('<=', 0), 'M_BC220_2': ('<=', 0), 'M_DS220_14': ('<=', 0), 'M_DS220_15': ('<=', 0), 'M_TF_1': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 45, Unk. prob.: 1.595e-02
# Surv probs: 2.000e-05, Fail probs: 9.840e-01
# No. of non-dominant rules: 44, Survival rules: 3, Failure rules: 41
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 27): {'M_Line220_1': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 46, Unk. prob.: 1.570e-02
# Surv probs: 0.000e+00, Fail probs: 9.843e-01
# No. of non-dominant rules: 45, Survival rules: 4, Failure rules: 41
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Bus110_1': ('<=', 0), 'M_DS110_29': ('<=', 0), 'M_DS110_30': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 47, Unk. prob.: 1.570e-02
# Surv probs: 1.000e-05, Fail probs: 9.843e-01
# No. of non-dominant rules: 46, Survival rules: 4, Failure rules: 42
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 48, Unk. prob.: 1.603e-02
# Surv probs: 1.000e-05, Fail probs: 9.840e-01
# No. of non-dominant rules: 47, Survival rules: 4, Failure rules: 43
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Bus110_1': ('<=', 0), 'M_DS110_23': ('<=', 0), 'M_Line110_6': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 49, Unk. prob.: 1.445e-02
# Surv probs: 1.000e-05, Fail probs: 9.855e-01
# No. of non-dominant rules: 48, Survival rules: 4, Failure rules: 44
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_TF_4': ('<=', 0), 'M_DS110_3': ('<=', 0), 'M_Bus110_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 50, Unk. prob.: 1.598e-02
# Surv probs: 0.000e+00, Fail probs: 9.840e-01
# No. of non-dominant rules: 49, Survival rules: 4, Failure rules: 45
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_DS110_14': ('<=', 0), 'M_DS110_26': ('<=', 0), 'M_Line110_6': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 51, Unk. prob.: 1.466e-02
# Surv probs: 0.000e+00, Fail probs: 9.853e-01
# No. of non-dominant rules: 50, Survival rules: 4, Failure rules: 46
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 294.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_2': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 52, Unk. prob.: 1.429e-02
# Surv probs: 0.000e+00, Fail probs: 9.857e-01
# No. of non-dominant rules: 51, Survival rules: 4, Failure rules: 47
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_2': ('<=', 0), 'M_Line110_9': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 53, Unk. prob.: 1.452e-02
# Surv probs: 2.000e-05, Fail probs: 9.855e-01
# No. of non-dominant rules: 52, Survival rules: 4, Failure rules: 48
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_6': ('<=', 0), 'M_Line110_11': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 54, Unk. prob.: 1.352e-02
# Surv probs: 1.000e-05, Fail probs: 9.865e-01
# No. of non-dominant rules: 53, Survival rules: 4, Failure rules: 49
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_DS110_9': ('<=', 0), 'M_DS110_21': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_4': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 55, Unk. prob.: 1.395e-02
# Surv probs: 0.000e+00, Fail probs: 9.860e-01
# No. of non-dominant rules: 54, Survival rules: 4, Failure rules: 50
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_4': ('<=', 0), 'M_Line110_9': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 56, Unk. prob.: 1.279e-02
# Surv probs: 2.000e-05, Fail probs: 9.872e-01
# No. of non-dominant rules: 55, Survival rules: 4, Failure rules: 51
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_5': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'M_Line110_9': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 57, Unk. prob.: 1.253e-02
# Surv probs: 0.000e+00, Fail probs: 9.875e-01
# No. of non-dominant rules: 56, Survival rules: 4, Failure rules: 52
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 26): {'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 58, Unk. prob.: 1.296e-02
# Surv probs: 3.000e-05, Fail probs: 9.870e-01
# No. of non-dominant rules: 57, Survival rules: 5, Failure rules: 52
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Bus110_2': ('<=', 0), 'M_DS110_17': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 59, Unk. prob.: 1.234e-02
# Surv probs: 4.000e-05, Fail probs: 9.876e-01
# No. of non-dominant rules: 58, Survival rules: 5, Failure rules: 53
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 26): {'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_11': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 60, Unk. prob.: 1.257e-02
# Surv probs: 2.000e-05, Fail probs: 9.874e-01
# No. of non-dominant rules: 59, Survival rules: 6, Failure rules: 53
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_DS110_9': ('<=', 0), 'M_DS110_21': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 61, Unk. prob.: 1.209e-02
# Surv probs: 1.000e-05, Fail probs: 9.879e-01
# No. of non-dominant rules: 60, Survival rules: 6, Failure rules: 54
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 0.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_Bus110_1': ('<=', 0), 'M_Bus110_2': ('<=', 0), 'sys': ('<=', 1)}
# Updated sys_vals: [0.0, 180.0, 216.0, 240.0, 264.0, 288.0, 290.0, 292.0, 294.0, 300]
# ---
# Round: 62, Unk. prob.: 1.247e-02
# Surv probs: 1.000e-05, Fail probs: 9.875e-01
# No. of non-dominant rules: 61, Survival rules: 6, Failure rules: 55
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Bus220_2': ('<=', 0), 'M_DS220_15': ('<=', 0), 'M_TF_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 63, Unk. prob.: 1.226e-02
# Surv probs: 1.000e-05, Fail probs: 9.877e-01
# No. of non-dominant rules: 62, Survival rules: 6, Failure rules: 56
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_DS110_16': ('<=', 0), 'M_DS110_28': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_9': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 64, Unk. prob.: 1.172e-02
# Surv probs: 1.000e-05, Fail probs: 9.883e-01
# No. of non-dominant rules: 63, Survival rules: 6, Failure rules: 57
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 28): {'M_Line220_1': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_11': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 65, Unk. prob.: 1.148e-02
# Surv probs: 1.000e-05, Fail probs: 9.885e-01
# No. of non-dominant rules: 64, Survival rules: 7, Failure rules: 57
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 264.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_DS220_1': ('<=', 0), 'M_DS220_3': ('<=', 0), 'M_Bus220_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 66, Unk. prob.: 1.228e-02
# Surv probs: 2.000e-05, Fail probs: 9.877e-01
# No. of non-dominant rules: 65, Survival rules: 7, Failure rules: 58
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_3': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_11': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 67, Unk. prob.: 1.113e-02
# Surv probs: 1.000e-05, Fail probs: 9.889e-01
# No. of non-dominant rules: 66, Survival rules: 7, Failure rules: 59
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 33): {'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 68, Unk. prob.: 1.191e-02
# Surv probs: 1.000e-05, Fail probs: 9.881e-01
# No. of non-dominant rules: 67, Survival rules: 8, Failure rules: 59
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 29): {'M_Line220_1': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_11': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 69, Unk. prob.: 1.211e-02
# Surv probs: 1.000e-05, Fail probs: 9.879e-01
# No. of non-dominant rules: 68, Survival rules: 9, Failure rules: 59
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_DS110_7': ('<=', 0), 'M_DS110_19': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_9': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 70, Unk. prob.: 1.160e-02
# Surv probs: 1.000e-05, Fail probs: 9.884e-01
# No. of non-dominant rules: 69, Survival rules: 9, Failure rules: 60
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_DS110_10': ('<=', 0), 'M_DS110_22': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_3': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 71, Unk. prob.: 1.068e-02
# Surv probs: 5.000e-05, Fail probs: 9.893e-01
# No. of non-dominant rules: 70, Survival rules: 9, Failure rules: 61
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_Bus110_1': ('<=', 0), 'M_DS110_20': ('<=', 0), 'M_Line110_1': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_11': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 72, Unk. prob.: 1.201e-02
# Surv probs: 3.000e-05, Fail probs: 9.880e-01
# No. of non-dominant rules: 71, Survival rules: 9, Failure rules: 62
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_3': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_6': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 73, Unk. prob.: 1.115e-02
# Surv probs: 2.000e-05, Fail probs: 9.888e-01
# No. of non-dominant rules: 72, Survival rules: 9, Failure rules: 63
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 294.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 74, Unk. prob.: 1.102e-02
# Surv probs: 0.000e+00, Fail probs: 9.890e-01
# No. of non-dominant rules: 73, Survival rules: 9, Failure rules: 64
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_DS110_16': ('<=', 0), 'M_DS110_28': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_9': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 75, Unk. prob.: 1.071e-02
# Surv probs: 3.000e-05, Fail probs: 9.893e-01
# No. of non-dominant rules: 74, Survival rules: 9, Failure rules: 65
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 28): {'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 76, Unk. prob.: 1.010e-02
# Surv probs: 0.000e+00, Fail probs: 9.899e-01
# No. of non-dominant rules: 75, Survival rules: 10, Failure rules: 65
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 27): {'M_Line220_1': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_11': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 77, Unk. prob.: 1.109e-02
# Surv probs: 1.000e-05, Fail probs: 9.889e-01
# No. of non-dominant rules: 76, Survival rules: 11, Failure rules: 65
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_Bus110_1': ('<=', 0), 'M_DS110_23': ('<=', 0), 'M_DS110_30': ('<=', 0), 'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 78, Unk. prob.: 1.061e-02
# Surv probs: 4.000e-05, Fail probs: 9.893e-01
# No. of non-dominant rules: 77, Survival rules: 11, Failure rules: 66
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 294.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 79, Unk. prob.: 1.123e-02
# Surv probs: 4.000e-05, Fail probs: 9.887e-01
# No. of non-dominant rules: 78, Survival rules: 11, Failure rules: 67
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Bus110_1': ('<=', 0), 'M_DS110_22': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_6': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 80, Unk. prob.: 1.069e-02
# Surv probs: 0.000e+00, Fail probs: 9.893e-01
# No. of non-dominant rules: 79, Survival rules: 11, Failure rules: 68
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_TF_2': ('<=', 0), 'M_TF_4': ('<=', 0), 'M_Bus110_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 81, Unk. prob.: 9.910e-03
# Surv probs: 0.000e+00, Fail probs: 9.901e-01
# No. of non-dominant rules: 80, Survival rules: 11, Failure rules: 69
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_DS110_10': ('<=', 0), 'M_DS110_22': ('<=', 0), 'M_Line110_3': ('<=', 0), 'M_Line110_7': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 82, Unk. prob.: 9.920e-03
# Surv probs: 4.000e-05, Fail probs: 9.900e-01
# No. of non-dominant rules: 81, Survival rules: 11, Failure rules: 70
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 0, System value: 216.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line220_6': ('<=', 0), 'M_DS220_10': ('<=', 0), 'M_Bus220_1': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 83, Unk. prob.: 9.610e-03
# Surv probs: 1.000e-05, Fail probs: 9.904e-01
# No. of non-dominant rules: 82, Survival rules: 11, Failure rules: 71
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 84, Unk. prob.: 1.046e-02
# Surv probs: 1.000e-05, Fail probs: 9.895e-01
# No. of non-dominant rules: 83, Survival rules: 11, Failure rules: 72
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_DS110_17': ('<=', 0), 'M_DS110_29': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 85, Unk. prob.: 9.730e-03
# Surv probs: 1.000e-05, Fail probs: 9.903e-01
# No. of non-dominant rules: 84, Survival rules: 11, Failure rules: 73
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_TF_1': ('<=', 0), 'M_DS110_5': ('<=', 0), 'M_Bus110_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 86, Unk. prob.: 9.220e-03
# Surv probs: 4.000e-05, Fail probs: 9.907e-01
# No. of non-dominant rules: 85, Survival rules: 11, Failure rules: 74
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_Bus110_1': ('<=', 0), 'M_DS110_20': ('<=', 0), 'M_Line110_1': ('<=', 0), 'M_Line110_6': ('<=', 0), 'M_Line110_11': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 87, Unk. prob.: 9.350e-03
# Surv probs: 4.000e-05, Fail probs: 9.906e-01
# No. of non-dominant rules: 86, Survival rules: 11, Failure rules: 75
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_DS110_9': ('<=', 0), 'M_DS110_21': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_5': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 88, Unk. prob.: 1.008e-02
# Surv probs: 2.000e-05, Fail probs: 9.899e-01
# No. of non-dominant rules: 87, Survival rules: 11, Failure rules: 76
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 6): {'M_DS110_7': ('<=', 0), 'M_DS110_15': ('<=', 0), 'M_DS110_19': ('<=', 0), 'M_DS110_27': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_4': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 89, Unk. prob.: 9.590e-03
# Surv probs: 1.000e-05, Fail probs: 9.904e-01
# No. of non-dominant rules: 88, Survival rules: 11, Failure rules: 77
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_8': ('<=', 0), 'M_Line110_9': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 90, Unk. prob.: 9.640e-03
# Surv probs: 1.000e-05, Fail probs: 9.903e-01
# No. of non-dominant rules: 89, Survival rules: 11, Failure rules: 78
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 27): {'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 91, Unk. prob.: 8.670e-03
# Surv probs: 2.000e-05, Fail probs: 9.913e-01
# No. of non-dominant rules: 90, Survival rules: 12, Failure rules: 78
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# ...
# ---
# Round: 101, Unk. prob.: 8.600e-03
# Surv probs: 4.000e-05, Fail probs: 9.914e-01
# No. of non-dominant rules: 100, Survival rules: 17, Failure rules: 83
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 240.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line220_4': ('<=', 0), 'M_DS220_6': ('<=', 0), 'M_Bus220_1': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 102, Unk. prob.: 8.950e-03
# Surv probs: 4.000e-05, Fail probs: 9.910e-01
# No. of non-dominant rules: 101, Survival rules: 17, Failure rules: 84
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_10': ('<=', 0), 'M_Line110_11': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 103, Unk. prob.: 9.430e-03
# Surv probs: 2.000e-05, Fail probs: 9.906e-01
# No. of non-dominant rules: 102, Survival rules: 17, Failure rules: 85
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_DS220_14': ('<=', 0), 'M_DS220_17': ('<=', 0), 'M_TF_1': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 104, Unk. prob.: 8.940e-03
# Surv probs: 2.000e-05, Fail probs: 9.910e-01
# No. of non-dominant rules: 103, Survival rules: 17, Failure rules: 86
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 294.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_DS110_15': ('<=', 0), 'M_DS110_27': ('<=', 0), 'M_Line110_1': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 105, Unk. prob.: 8.730e-03
# Surv probs: 2.000e-05, Fail probs: 9.912e-01
# No. of non-dominant rules: 104, Survival rules: 17, Failure rules: 87
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 6): {'M_DS110_7': ('<=', 0), 'M_DS110_18': ('<=', 0), 'M_DS110_19': ('<=', 0), 'M_DS110_30': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_7': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 106, Unk. prob.: 9.100e-03
# Surv probs: 5.000e-05, Fail probs: 9.909e-01
# No. of non-dominant rules: 105, Survival rules: 17, Failure rules: 88
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 6): {'M_TF_1': ('<=', 0), 'M_DS110_3': ('<=', 0), 'M_DS110_5': ('<=', 0), 'M_BC110_1': ('<=', 0), 'M_DS110_29': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 107, Unk. prob.: 8.670e-03
# Surv probs: 1.000e-05, Fail probs: 9.913e-01
# No. of non-dominant rules: 106, Survival rules: 17, Failure rules: 89
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 5): {'M_DS110_11': ('<=', 0), 'M_DS110_23': ('<=', 0), 'M_Line110_1': ('<=', 0), 'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 108, Unk. prob.: 8.330e-03
# Surv probs: 2.000e-05, Fail probs: 9.917e-01
# No. of non-dominant rules: 107, Survival rules: 17, Failure rules: 90
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_5': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 109, Unk. prob.: 8.980e-03
# Surv probs: 2.000e-05, Fail probs: 9.910e-01
# No. of non-dominant rules: 108, Survival rules: 17, Failure rules: 91
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 292.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Line110_3': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_8': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 110, Unk. prob.: 8.550e-03
# Surv probs: 1.000e-05, Fail probs: 9.914e-01
# No. of non-dominant rules: 109, Survival rules: 17, Failure rules: 92
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_TF_2': ('<=', 0), 'M_TF_4': ('<=', 0), 'M_DS110_2': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 111, Unk. prob.: 8.700e-03
# Surv probs: 1.000e-05, Fail probs: 9.913e-01
# No. of non-dominant rules: 110, Survival rules: 17, Failure rules: 93
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 290.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_7': ('<=', 0), 'M_Line110_8': ('<=', 0), 'M_Line110_10': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 112, Unk. prob.: 7.800e-03
# Surv probs: 7.000e-05, Fail probs: 9.921e-01
# No. of non-dominant rules: 111, Survival rules: 17, Failure rules: 94
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_5': ('<=', 0), 'M_Line110_12': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 113, Unk. prob.: 8.010e-03
# Surv probs: 4.000e-05, Fail probs: 9.919e-01
# No. of non-dominant rules: 112, Survival rules: 17, Failure rules: 95
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Bus110_2': ('<=', 0), 'M_DS110_12': ('<=', 0), 'M_Line110_9': ('<=', 0), 'M_Line110_10': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 114, Unk. prob.: 8.280e-03
# Surv probs: 5.000e-05, Fail probs: 9.917e-01
# No. of non-dominant rules: 113, Survival rules: 17, Failure rules: 96
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 29): {'M_Line220_1': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 115, Unk. prob.: 7.860e-03
# Surv probs: 2.000e-05, Fail probs: 9.921e-01
# No. of non-dominant rules: 114, Survival rules: 18, Failure rules: 96
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 294.0. Total samples: 100000.
# New rule (No. of conditions: 4): {'M_Line110_1': ('<=', 0), 'M_Line110_2': ('<=', 0), 'M_Line110_4': ('<=', 0), 'M_Line110_7': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 116, Unk. prob.: 7.430e-03
# Surv probs: 4.000e-05, Fail probs: 9.925e-01
# No. of non-dominant rules: 115, Survival rules: 18, Failure rules: 97
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 29): {'M_Line220_1': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_2': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 117, Unk. prob.: 7.390e-03
# Surv probs: 0.000e+00, Fail probs: 9.926e-01
# No. of non-dominant rules: 116, Survival rules: 19, Failure rules: 97
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 27): {'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_11': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 118, Unk. prob.: 7.360e-03
# Surv probs: 2.000e-05, Fail probs: 9.926e-01
# No. of non-dominant rules: 117, Survival rules: 20, Failure rules: 97
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 26): {'M_Line220_1': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 119, Unk. prob.: 7.350e-03
# Surv probs: 3.000e-05, Fail probs: 9.926e-01
# No. of non-dominant rules: 118, Survival rules: 21, Failure rules: 97
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_TF_2': ('<=', 0), 'M_DS110_6': ('<=', 0), 'M_Bus110_1': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 120, Unk. prob.: 7.210e-03
# Surv probs: 3.000e-05, Fail probs: 9.928e-01
# No. of non-dominant rules: 119, Survival rules: 21, Failure rules: 98
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 28): {'M_Line220_1': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 121, Unk. prob.: 7.600e-03
# Surv probs: 3.000e-05, Fail probs: 9.924e-01
# No. of non-dominant rules: 120, Survival rules: 22, Failure rules: 98
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 2, System value: 300. Total samples: 100000.
# New rule (No. of conditions: 27): {'M_Line220_2': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 2)}
# ---
# Round: 122, Unk. prob.: 7.570e-03
# Surv probs: 3.000e-05, Fail probs: 9.924e-01
# No. of non-dominant rules: 121, Survival rules: 23, Failure rules: 98
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Bus220_2': ('<=', 0), 'M_DS220_15': ('<=', 0), 'M_TF_1': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 123, Unk. prob.: 7.870e-03
# Surv probs: 6.000e-05, Fail probs: 9.921e-01
# No. of non-dominant rules: 122, Survival rules: 23, Failure rules: 99
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: 1, System value: 288.0. Total samples: 100000.
# New rule (No. of conditions: 3): {'M_Bus110_1': ('<=', 0), 'M_DS110_24': ('<=', 0), 'M_Line110_5': ('<=', 0), 'sys': ('<=', 1)}
# ---
# Round: 124, Unk. prob.: 7.570e-03
# Surv probs: 3.000e-05, Fail probs: 9.924e-01
# No. of non-dominant rules: 123, Survival rules: 23, Failure rules: 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 8
#       5 probs = [[probs_dict[n]['0']['p'], probs_dict[n]['1']['p']] for n in row_names]
#       6 probs = torch.tensor(probs, dtype=torch.float32, device=device)
# ----> 8 result = tsum.run_rule_extraction_by_mcs(
#       9     sfun = sfun_subs,
#      10     probs = probs,
#      11     row_names = row_names,
#      12     n_state = n_state,
#      13     output_dir = "tsum_res",
#      14     unk_prob_thres = 1e-3,
#      15     sys_surv_st = sys_surv_st
#      16 )
#
# File c:\Users\jb622s\git\tsum\tsum\tsum.py:1765, in run_rule_extraction_by_mcs(sfun, probs, row_names, n_state, sys_surv_st, rules_surv, rules_fail, rules_mat_surv, rules_mat_fail, unk_prob_thres, unk_prob_opt, prob_update_every, save_every, n_sample, sample_batch_size, min_rule_search, rule_update_verbose, output_dir, surv_json_name, fail_json_name, surv_pt_name, fail_pt_name, metrics_path)
#    1763 for i in range(total_loops):
#    1764     samples = sample_categorical(probs, sample_batch_size)  # (B, n_var, n_state)
# -> 1765     res = classify_samples_with_indices(samples, rules_mat_surv, rules_mat_fail, return_masks=True)
#    1767     counts["survival"] += int(res["survival"])
#    1768     counts["failure"]  += int(res["failure"])
#
# File c:\Users\jb622s\git\tsum\tsum\tsum.py:1534, in classify_samples_with_indices(samples, survival_rules, failure_rules, return_masks)
#    1531 is_subset = torch.all((current_samples & rule_tensor) == current_samples, dim=(1, 2))
#    1533 # Map back to original indices
# -> 1534 idx_all = torch.where(unclassified_idx)[0]
#    1535 matched_idx = idx_all[is_subset]
#    1537 if matched_idx.numel() == 0:
#
# KeyboardInterrupt:
