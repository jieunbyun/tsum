# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent.parent))  # add repo root
from tsum import tsum
import torch
import json, os

from pathlib import Path 

from distribution_substation_liang2022.v1.scripts import utils_sub # available at github.com/jieunbyun/network-datasets 

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
DATASET = Path("data") 

nodes = json.loads((DATASET / "nodes.json").read_text(encoding="utf-8"))
edges = json.loads((DATASET / "edges.json").read_text(encoding="utf-8"))

row_names = list(edges.keys()) + ['sys']

n_comp = len(edges)
n_var = n_comp + 1  # components + system
n_state = 2 # binary states: working (1) or failed (0)

# %%
def sfun_subs(comps_st, thres=360):
    node_groups = utils_sub.process_nodes(nodes)
    capacity = utils_sub.sys_fun(comps_st, edges, nodes, node_groups, return_details=False)

    if capacity >= thres:
        return capacity, 's', None
    else:
        return capacity, 'f', None

# %% [markdown]
# # Find rules over thresholds

# %%
pga_str_list = ['0_1g', '0_2g', '0_3g', '0_4g', '0_5g']

# Threshold values to start with
if os.path.exists(r"tsum_res/thres_list.json"):
    with open(r"tsum_res/thres_list.json", "r") as f:
        thres_list = json.load(f)
        thres_isdone = [False]*len(thres_list)

        if 0 in thres_list: 
            idx_0 = thres_list.index(0)
            thres_isdone[idx_0] = True  # 0 threshold doesn't need to be computed
else:
    thres_list = [360]
    thres_isdone = [False]
    with open(r"tsum_res/thres_list.json", "w") as f:
        json.dump(thres_list, f, indent=4)

while not all(thres_isdone):

    # get the next highest threshold to compute
    i, t = next((i, t) for i, (t, done) in enumerate(zip(thres_list, thres_isdone)) if not done)
    thres_isdone[i] = True
    print(f"Threshold: {t}..")

    # now loop over all PGA values inside this threshold
    for pga_str in pga_str_list:
        print(f"--- {pga_str} ---")

        with open(rf"data\probs_{pga_str}.json", "r") as f: 
            probs_dict = json.load(f)

        probs = [[probs_dict[n]['0']['p'], probs_dict[n]['1']['p']] for n in row_names[:-1]]
        probs = torch.tensor(probs, dtype=torch.float32, device=device)

        # initialisation
        sfun = lambda comps_st: sfun_subs(comps_st, thres=t)

        # Load previous rules if available from previous runs
        if os.path.exists(Path("tsum_res") / f"rules_surv_{t}.json"):
            rules_surv = json.loads((Path("tsum_res") / f"rules_surv_{t}.json").read_text(encoding="utf-8"))
            rules_fail = json.loads((Path("tsum_res") / f"rules_fail_{t}.json").read_text(encoding="utf-8"))
            rules_mat_surv = torch.load(Path("tsum_res") / f"rules_surv_{t}.pt", map_location="cpu").to(device)
            rules_mat_fail = torch.load(Path("tsum_res") / f"rules_fail_{t}.pt", map_location="cpu").to(device)
        else:
            rules_surv = []
            rules_fail = []
            rules_mat_surv = None
            rules_mat_fail = None

        # run rule extraction: two options available: tsum.run_rule_extraction or tsum.run_rule_extraction_by_mcs
        # result = tsum.run_rule_extraction(
        result = tsum.run_rule_extraction_by_mcs(
            sfun = sfun,
            probs = probs,
            row_names = row_names,
            n_state = n_state,
            rules_surv = rules_surv,
            rules_fail = rules_fail,
            rules_mat_surv = rules_mat_surv,
            rules_mat_fail = rules_mat_fail,
            #stochastic_search = False,
            output_dir = "tsum_res",
            surv_json_name = f"rules_surv_{t}.json",
            fail_json_name = f"rules_fail_{t}.json",
            surv_pt_name = f"rules_surv_{t}.pt",
            fail_pt_name = f"rules_fail_{t}.pt",
            metrics_path = f"metrics_{t}_{pga_str}.jsonl",
            unk_prob_thres = 1e-6,
        )

        # update threshold list after processing all PGA values
        for s in result['sys_vals']:
            s = int(s)
            if s not in thres_list:
                thres_list.append(s)
                thres_isdone.append(s == 0)
                pairs = list(zip(thres_list, thres_isdone))
                pairs.sort(key=lambda x: x[0], reverse=True)
                thres_list, thres_isdone = map(list, zip(*pairs))

        print(f"Updated thres_list: {thres_list}")
        with open(r"tsum_res/thres_list.json", "w") as f:
            json.dump(thres_list, f, indent=4)
# Out:
# Threshold: 360..
# --- 0_1g ---
# ---
# Round: 1, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 0, Survival rules: 0, Failure rules: 0
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# Updated sys_vals: [360.0]
# ---
# Round: 2, Unk. prob.: 1.000e+00
# No. of non-dominant rules: 1, Survival rules: 1, Failure rules: 0
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_2': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [360.0, None]
# ---
# Round: 3, Unk. prob.: 2.618e-01
# No. of non-dominant rules: 2, Survival rules: 1, Failure rules: 1
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_7': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 4, Unk. prob.: 2.438e-01
# No. of non-dominant rules: 3, Survival rules: 1, Failure rules: 2
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 5, Unk. prob.: 2.294e-01
# No. of non-dominant rules: 4, Survival rules: 2, Failure rules: 2
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 348.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_5': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [348.0, 360.0, None]
# ---
# Round: 6, Unk. prob.: 2.019e-01
# No. of non-dominant rules: 5, Survival rules: 2, Failure rules: 3
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 7, Unk. prob.: 1.872e-01
# No. of non-dominant rules: 6, Survival rules: 3, Failure rules: 3
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 8, Unk. prob.: 1.549e-01
# No. of non-dominant rules: 7, Survival rules: 4, Failure rules: 3
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_8': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 9, Unk. prob.: 1.368e-01
# No. of non-dominant rules: 8, Survival rules: 4, Failure rules: 4
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_3': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 10, Unk. prob.: 1.235e-01
# No. of non-dominant rules: 9, Survival rules: 4, Failure rules: 5
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 350.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_9': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [348.0, 350.0, 360.0, None]
# ---
# Round: 11, Unk. prob.: 1.102e-01
# No. of non-dominant rules: 10, Survival rules: 4, Failure rules: 6
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 12, Unk. prob.: 9.610e-02
# No. of non-dominant rules: 11, Survival rules: 5, Failure rules: 6
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_11': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 13, Unk. prob.: 8.231e-02
# No. of non-dominant rules: 12, Survival rules: 5, Failure rules: 7
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 14, Unk. prob.: 6.869e-02
# No. of non-dominant rules: 13, Survival rules: 5, Failure rules: 8
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 15, Unk. prob.: 5.670e-02
# No. of non-dominant rules: 14, Survival rules: 6, Failure rules: 8
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_4': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 16, Unk. prob.: 5.409e-02
# No. of non-dominant rules: 15, Survival rules: 6, Failure rules: 9
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_12': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 17, Unk. prob.: 4.135e-02
# No. of non-dominant rules: 16, Survival rules: 6, Failure rules: 10
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_6': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 18, Unk. prob.: 2.920e-02
# No. of non-dominant rules: 17, Survival rules: 6, Failure rules: 11
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line110_10': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 19, Unk. prob.: 1.625e-02
# No. of non-dominant rules: 18, Survival rules: 6, Failure rules: 12
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 20, Unk. prob.: 3.820e-03
# No. of non-dominant rules: 19, Survival rules: 7, Failure rules: 12
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_2': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 21, Unk. prob.: 3.210e-03
# No. of non-dominant rules: 20, Survival rules: 8, Failure rules: 12
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 22, Unk. prob.: 2.690e-03
# No. of non-dominant rules: 21, Survival rules: 9, Failure rules: 12
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_TF_1': ('<=', 0), 'M_TF_3': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 23, Unk. prob.: 2.230e-03
# No. of non-dominant rules: 22, Survival rules: 9, Failure rules: 13
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 24, Unk. prob.: 1.980e-03
# No. of non-dominant rules: 23, Survival rules: 10, Failure rules: 13
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_10': ('<=', 0), 'M_DS110_22': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 25, Unk. prob.: 1.640e-03
# No. of non-dominant rules: 24, Survival rules: 10, Failure rules: 14
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 26, Unk. prob.: 1.700e-03
# No. of non-dominant rules: 25, Survival rules: 11, Failure rules: 14
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_14': ('<=', 0), 'M_DS110_26': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 27, Unk. prob.: 1.460e-03
# No. of non-dominant rules: 26, Survival rules: 11, Failure rules: 15
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_16': ('<=', 0), 'M_DS110_28': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 28, Unk. prob.: 1.440e-03
# No. of non-dominant rules: 27, Survival rules: 11, Failure rules: 16
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 29, Unk. prob.: 1.670e-03
# No. of non-dominant rules: 28, Survival rules: 12, Failure rules: 16
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_TF_2': ('<=', 0), 'M_TF_3': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 30, Unk. prob.: 1.080e-03
# No. of non-dominant rules: 29, Survival rules: 12, Failure rules: 17
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 180.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_TF_1': ('<=', 0), 'M_TF_2': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [180.0, 348.0, 350.0, 360.0, None]
# ---
# Round: 31, Unk. prob.: 8.100e-04
# No. of non-dominant rules: 30, Survival rules: 12, Failure rules: 18
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_BC220_1': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 32, Unk. prob.: 7.800e-04
# No. of non-dominant rules: 31, Survival rules: 13, Failure rules: 18
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_11': ('<=', 0), 'M_DS110_23': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 33, Unk. prob.: 6.400e-04
# No. of non-dominant rules: 32, Survival rules: 13, Failure rules: 19
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 34, Unk. prob.: 4.900e-04
# No. of non-dominant rules: 33, Survival rules: 14, Failure rules: 19
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 344.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line220_1': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [180.0, 344.0, 348.0, 350.0, 360.0, None]
# ---
# Round: 35, Unk. prob.: 4.500e-04
# No. of non-dominant rules: 34, Survival rules: 14, Failure rules: 20
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 348.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_18': ('<=', 0), 'M_DS110_30': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 36, Unk. prob.: 4.200e-04
# No. of non-dominant rules: 35, Survival rules: 14, Failure rules: 21
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_9': ('<=', 0), 'M_DS110_21': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 37, Unk. prob.: 4.200e-04
# No. of non-dominant rules: 36, Survival rules: 14, Failure rules: 22
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 38, Unk. prob.: 3.400e-04
# No. of non-dominant rules: 37, Survival rules: 15, Failure rules: 22
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 39, Unk. prob.: 5.300e-04
# No. of non-dominant rules: 38, Survival rules: 16, Failure rules: 22
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 40, Unk. prob.: 3.500e-04
# No. of non-dominant rules: 39, Survival rules: 17, Failure rules: 22
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_12': ('<=', 0), 'M_DS110_24': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 41, Unk. prob.: 3.500e-04
# No. of non-dominant rules: 40, Survival rules: 17, Failure rules: 23
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_17': ('<=', 0), 'M_DS110_29': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 42, Unk. prob.: 3.900e-04
# No. of non-dominant rules: 41, Survival rules: 17, Failure rules: 24
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 43, Unk. prob.: 4.000e-04
# No. of non-dominant rules: 42, Survival rules: 18, Failure rules: 24
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 44, Unk. prob.: 1.800e-04
# No. of non-dominant rules: 43, Survival rules: 19, Failure rules: 24
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 352.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_7': ('<=', 0), 'M_DS110_19': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [180.0, 344.0, 348.0, 350.0, 352.0, 360.0, None]
# ---
# Round: 45, Unk. prob.: 2.400e-04
# No. of non-dominant rules: 44, Survival rules: 19, Failure rules: 25
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_13': ('<=', 0), 'M_DS110_25': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 46, Unk. prob.: 1.700e-04
# No. of non-dominant rules: 45, Survival rules: 19, Failure rules: 26
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_8': ('<=', 0), 'M_DS110_20': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 47, Unk. prob.: 1.600e-04
# No. of non-dominant rules: 46, Survival rules: 19, Failure rules: 27
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 340.0. Total samples: 100000.
# New rule (No. of conditions: 1): {'M_Line220_3': ('<=', 0), 'sys': ('<=', 0)}
# Updated sys_vals: [180.0, 340.0, 344.0, 348.0, 350.0, 352.0, 360.0, None]
# ---
# Round: 48, Unk. prob.: 1.900e-04
# No. of non-dominant rules: 47, Survival rules: 19, Failure rules: 28
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 49, Unk. prob.: 1.600e-04
# No. of non-dominant rules: 48, Survival rules: 20, Failure rules: 28
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 50, Unk. prob.: 1.300e-04
# No. of non-dominant rules: 49, Survival rules: 21, Failure rules: 28
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 51, Unk. prob.: 1.100e-04
# No. of non-dominant rules: 50, Survival rules: 22, Failure rules: 28
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 52, Unk. prob.: 1.100e-04
# No. of non-dominant rules: 51, Survival rules: 23, Failure rules: 28
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 53, Unk. prob.: 1.500e-04
# No. of non-dominant rules: 52, Survival rules: 24, Failure rules: 28
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_14': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 54, Unk. prob.: 9.000e-05
# No. of non-dominant rules: 53, Survival rules: 25, Failure rules: 28
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: None. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS110_15': ('<=', 0), 'M_DS110_27': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 55, Unk. prob.: 8.000e-05
# No. of non-dominant rules: 54, Survival rules: 25, Failure rules: 29
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# ...
# No. of non-dominant rules: 249, Survival rules: 178, Failure rules: 71
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 138, Unk. prob.: 8.900e-04
# No. of non-dominant rules: 250, Survival rules: 179, Failure rules: 71
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 139, Unk. prob.: 9.400e-04
# No. of non-dominant rules: 251, Survival rules: 180, Failure rules: 71
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 140, Unk. prob.: 8.000e-04
# No. of non-dominant rules: 252, Survival rules: 181, Failure rules: 71
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 47): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_BC110_1': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 141, Unk. prob.: 7.000e-04
# No. of non-dominant rules: 253, Survival rules: 182, Failure rules: 71
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_9': ('>=', 1), 'M_DS220_11': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_DS220_13': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_21': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_26': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 142, Unk. prob.: 9.600e-04
# No. of non-dominant rules: 254, Survival rules: 183, Failure rules: 71
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_18': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_6': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 143, Unk. prob.: 7.900e-04
# No. of non-dominant rules: 255, Survival rules: 184, Failure rules: 71
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_4': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_10': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_16': ('>=', 1), 'M_DS110_17': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_20': ('>=', 1), 'M_DS110_23': ('>=', 1), 'M_DS110_27': ('>=', 1), 'M_DS110_30': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 144, Unk. prob.: 7.900e-04
# No. of non-dominant rules: 256, Survival rules: 185, Failure rules: 71
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 352.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_Bus110_1': ('<=', 0), 'M_DS110_26': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 145, Unk. prob.: 9.900e-04
# No. of non-dominant rules: 257, Survival rules: 185, Failure rules: 72
# Failure sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: f, System value: 344.0. Total samples: 100000.
# New rule (No. of conditions: 2): {'M_DS220_4': ('<=', 0), 'M_Bus220_1': ('<=', 0), 'sys': ('<=', 0)}
# ---
# Round: 146, Unk. prob.: 7.700e-04
# No. of non-dominant rules: 258, Survival rules: 185, Failure rules: 73
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 46): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_1': ('>=', 1), 'M_DS220_3': ('>=', 1), 'M_DS220_5': ('>=', 1), 'M_DS220_7': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_1': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_15': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_TF_3': ('>=', 1), 'M_DS110_4': ('>=', 1), 'M_DS110_5': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_7': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_24': ('>=', 1), 'M_DS110_25': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 147, Unk. prob.: 8.600e-04
# No. of non-dominant rules: 259, Survival rules: 186, Failure rules: 73
# Survival sample found from sampling.
# No. of existing rules removed:  0
# New rule added. System state: s, System value: 360.0. Total samples: 100000.
# New rule (No. of conditions: 45): {'M_Line220_1': ('>=', 1), 'M_Line220_2': ('>=', 1), 'M_Line220_3': ('>=', 1), 'M_Line220_4': ('>=', 1), 'M_Line220_5': ('>=', 1), 'M_Line220_6': ('>=', 1), 'M_DS220_2': ('>=', 1), 'M_DS220_4': ('>=', 1), 'M_DS220_6': ('>=', 1), 'M_DS220_8': ('>=', 1), 'M_DS220_10': ('>=', 1), 'M_DS220_12': ('>=', 1), 'M_Bus220_2': ('>=', 1), 'M_DS220_16': ('>=', 1), 'M_DS220_17': ('>=', 1), 'M_TF_1': ('>=', 1), 'M_TF_2': ('>=', 1), 'M_DS110_2': ('>=', 1), 'M_DS110_3': ('>=', 1), 'M_Bus110_1': ('>=', 1), 'M_Bus110_2': ('>=', 1), 'M_DS110_8': ('>=', 1), 'M_DS110_9': ('>=', 1), 'M_DS110_11': ('>=', 1), 'M_DS110_12': ('>=', 1), 'M_DS110_13': ('>=', 1), 'M_DS110_14': ('>=', 1), 'M_DS110_15': ('>=', 1), 'M_DS110_18': ('>=', 1), 'M_DS110_19': ('>=', 1), 'M_DS110_22': ('>=', 1), 'M_DS110_28': ('>=', 1), 'M_DS110_29': ('>=', 1), 'M_Line110_1': ('>=', 1), 'M_Line110_2': ('>=', 1), 'M_Line110_3': ('>=', 1), 'M_Line110_4': ('>=', 1), 'M_Line110_5': ('>=', 1), 'M_Line110_6': ('>=', 1), 'M_Line110_7': ('>=', 1), 'M_Line110_8': ('>=', 1), 'M_Line110_9': ('>=', 1), 'M_Line110_10': ('>=', 1), 'M_Line110_11': ('>=', 1), 'M_Line110_12': ('>=', 1), 'sys': ('>=', 1)}
# ---
# Round: 148, Unk. prob.: 7.600e-04
# No. of non-dominant rules: 260, Survival rules: 187, Failure rules: 73
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 52
#      48     rules_mat_fail = None
#      50 # run rule extraction: two options available: tsum.run_rule_extraction or tsum.run_rule_extraction_by_mcs
#      51 # result = tsum.run_rule_extraction(
# ---> 52 result = tsum.run_rule_extraction_by_mcs(
#      53     sfun = sfun,
#      54     probs = probs,
#      55     row_names = row_names,
#      56     n_state = n_state,
#      57     rules_surv = rules_surv,
#      58     rules_fail = rules_fail,
#      59     rules_mat_surv = rules_mat_surv,
#      60     rules_mat_fail = rules_mat_fail,
#      61     #stochastic_search = False,
#      62     output_dir = "tsum_res",
#      63     surv_json_name = f"rules_surv_{t}.json",
#      64     fail_json_name = f"rules_fail_{t}.json",
#      65     surv_pt_name = f"rules_surv_{t}.pt",
#      66     fail_pt_name = f"rules_fail_{t}.pt",
#      67     metrics_path = f"metrics_{t}_{pga_str}.jsonl",
#      68     unk_prob_thres = 1e-6,
#      69 )
#      71 # update threshold list after processing all PGA values
#      72 for s in result['sys_vals']:
#
# File c:\Users\jb622s\git\tsum\tsum\tsum.py:2118, in run_rule_extraction_by_mcs(sfun, probs, row_names, n_state, rules_surv, rules_fail, rules_mat_surv, rules_mat_fail, unk_prob_thres, prob_update_every, save_every, n_sample, sample_batch_size, rule_search_batch_size, rule_search_max_iters, min_rule_search, rule_update_verbose, output_dir, surv_json_name, fail_json_name, surv_pt_name, fail_pt_name, metrics_path)
#    2115 samples = None
#    2116 i = -1
# -> 2118 for i in range(total_loops):
#    2119     samples = sample_categorical(probs, sample_batch_size)  # (B, n_var, n_state)
#    2120     res = classify_samples_with_indices(samples, rules_mat_surv, rules_mat_fail, return_masks=True)
#
# File c:\Users\jb622s\git\tsum\tsum\tsum.py:1754, in classify_samples_with_indices(samples, survival_rules, failure_rules, return_masks)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:

# %%
print(result['sys_vals'])
# Out:
# [180.0, 340.0, 348.0, 350.0, 352.0, 360.0, None]
